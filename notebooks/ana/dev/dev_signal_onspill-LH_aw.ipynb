# %% [markdown]
# # Analysis notebook: `dev_signal_onspill-LH_aw`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "dev_signal_onspill-LH_aw"

# %% [markdown]
# ## Preamble

# %%
import sys
sys.path.append("..")
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../../output/results/dev_signal_onspill-LH_aw
# Out:
# analysis.csv  dev_signal_onspill-LH_aw.log   hists.h5
# cut_flow.csv  dev_signal_onspill-LH_aw.yaml  results.pkl

# %%
loader = Load(
    in_path = f"../../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../../output/results/dev_signal_onspill-LH_aw

# %%
results = loader.load_pkl() 
# results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../../output/results/dev_signal_onspill-LH_aw/results.pkl

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                         Cut      Group  Events Passing  Absolute [%]  \
# 0                   No cuts        NaN         1493499           100
# 1                  thru_trk  Preselect         1493210        99.981
# 2          is_reco_electron  Preselect         1491960        99.897
# 3         one_reco_electron  Preselect         1487793        99.618
# 4             is_downstream  Preselect         1487787        99.618
# 5         is_truth_electron  Preselect         1487786        99.617
# 6              good_trkqual    Tracker         1352457        90.556
# 7                 within_t0    Tracker          980633        65.660
# 8              within_t0err    Tracker          944677        63.253
# 9                  has_hits    Tracker          915833        61.321
# 10                within_d0    Tracker          909901        60.924
# 11    within_pitch_angle_lo    Tracker          909791        60.917
# 12    within_pitch_angle_hi    Tracker          841131        56.319
# 13        within_lhr_max_hi    Tracker          841113        56.318
# 14  within_coinc_start_time        CRV          841113        56.318
# 15    within_coinc_end_time        CRV          841113        56.318
# 16                 unvetoed       Veto          841113        56.318
# 17          within_wide_win   Momentum          839291        56.196
# 18           within_ext_win   Momentum          794097        53.170
# 19           within_sig_win   Momentum          585461        39.201
#
#     Relative [%]                                  Description
# 0            100                         No selection applied
# 1         99.981                Tracks intersect full tracker
# 2         99.916             Select electron track hypothesis
# 3         99.721                    One reco electron / event
# 4            100  Downstream tracks (p_z > 0 through tracker)
# 5            100      Track parents are electrons (truth PID)
# 6         90.904                          Track quality > 0.2
# 7         72.508      t0 at tracker mid (640 < t_0 < 1650 ns)
# 8         96.333    Track fit t0 uncertainty (t0err < 0.9 ns)
# 9         96.947                      >20 active tracker hits
# 10        99.352  Distance of closest approach (d_0 < 100 mm)
# 11        99.988       Extrapolated pitch angle (pz/pt > 0.5)
# 12        92.453       Extrapolated pitch angle (pz/pt < 1.0)
# 13        99.998   Loop helix maximum radius (R_max < 680 mm)
# 14           100  Coincidence start time (t_start > 420.0 ns)
# 15           100     Coincidence end time (t_end < 1700.0 ns)
# 16           100                    Veto: 0.0 < dT < 150.0 ns
# 17        99.783             Wide window (85 < p < 200 MeV/c)
# 18        94.615        Extended window (100 < p < 110 MeV/c)
# 19        73.727      Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Efficiency & rates

# %%
display(results["analysis"])
# Out:
# Window                                             Inclusive      Wide  \
# Generated                                          4,000,000 4,000,000
# Selected                                             841,113   839,291
# Unvetoed                                             841,113   839,291
# Selection Eff [%]                                     21.028    20.982
# Selection Eff Err$-$ [%]                              -0.020    -0.020
# Selection Eff Err$+$ [%]                               0.020     0.020
# Veto Eff [%]                                               0         0
# Veto Eff Err$-$ [%]                                        0         0
# Veto Eff Err$+$ [%]                                 1.19e-04  1.19e-04
# Livetime [days]                                            0         0
# Walltime 1BB [days]                                        0         0
# Walltime 2BB [days]                                        0         0
# Selection Rate 1BB [$\text{day}^{-1}$]                     0         0
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]              0         0
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0         0
# Selection Rate 2BB [$\text{day}^{-1}$]                     0         0
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]              0         0
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0         0
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                      0         0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]               0         0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]               0         0
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                      0         0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]               0         0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]               0         0
# Run-1 Livetimes                                            0         0
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                 0         0
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]          0         0
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0         0
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                  0         0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]           0         0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0         0
#
# Window                                             Extended    Signal
# Generated                                         4,000,000 4,000,000
# Selected                                            794,097   585,461
# Unvetoed                                            794,097   585,461
# Selection Eff [%]                                    19.852    14.637
# Selection Eff Err$-$ [%]                             -0.020    -0.018
# Selection Eff Err$+$ [%]                              0.020     0.018
# Veto Eff [%]                                              0         0
# Veto Eff Err$-$ [%]                                       0         0
# Veto Eff Err$+$ [%]                                1.26e-04  1.71e-04
# Livetime [days]                                           0         0
# Walltime 1BB [days]                                       0         0
# Walltime 2BB [days]                                       0         0
# Selection Rate 1BB [$\text{day}^{-1}$]                    0         0
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             0         0
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]             0         0
# Selection Rate 2BB [$\text{day}^{-1}$]                    0         0
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             0         0
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]             0         0
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                     0         0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]              0         0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]              0         0
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                     0         0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]              0         0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]              0         0
# Run-1 Livetimes                                           0         0
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                0         0
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         0         0
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]         0         0
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                 0         0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]          0         0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0         0

# %% [markdown]
# ### Histograms

# %%
# Setup draw for this cutset
on_spill = "offspill" not in ana_label
draw = Draw(cutset_name=ana_label.split('_')[0], on_spill=on_spill)
# Define image directory
img_dir = f"../../../output/images/{ana_label}"
import os
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Load] ✅ Initialised with out_path=test_out
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw/h1o_1x3_mom_windows.png

# %%
draw.plot_summary(results["hists"], out_path=f"{img_dir}/h1o_3x3_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw/h1o_3x3_summary.png

# %%
draw.plot_mom_summary(results["hists"], out_path=f"{img_dir}/h1o_2x2_mom_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw/h1o_2x2_mom_summary.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_z.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw/h1o_crv_z.png

# %%
draw.draw_cosmic_parents_from_array(results["events"], out_path=f"{img_dir}/h1_cosmic_parents.png")
# Out:
# [Plot] ❌ Error extracting cosmic parents: 'NoneType' object is not subscriptable

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
# if results["events"] is not None:
#     from pyutils.pyprint import Print
#     printer = Print()
#     printer.print_n_events(results["events"], n_events = len(results["events"]))
