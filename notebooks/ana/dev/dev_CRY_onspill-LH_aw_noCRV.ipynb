# %% [markdown]
# # Analysis notebook: `dev_CRY_onspill-LH_aw_noCRV`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "dev_CRY_onspill-LH_aw_noCRV"

# %% [markdown]
# ## Preamble

# %%
import sys
sys.path.append("..")
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../../output/results/dev_CRY_onspill-LH_aw_noCRV
# Out:
# analysis.csv  dev_CRY_onspill-LH_aw_noCRV.log	events.parquet	info.txt
# cut_flow.csv  dev_CRY_onspill-LH_aw_noCRV.yaml	hists.h5	results.pkl

# %%
loader = Load(
    in_path = f"../../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../../output/results/dev_CRY_onspill-LH_aw_noCRV

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../../output/results/dev_CRY_onspill-LH_aw_noCRV/results.pkl
# [Load] ✅ Loaded cut stats from ../../../output/results/dev_CRY_onspill-LH_aw_noCRV/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../../output/results/dev_CRY_onspill-LH_aw_noCRV/hists.h5
# [Load] ✅ Loaded analysis info from ../../../output/results/dev_CRY_onspill-LH_aw_noCRV/analysis.csv
# [Load] ✅ Successfully loaded ak.Array from ../../../output/results/dev_CRY_onspill-LH_aw_noCRV/events.parquet
# [Load] ✅ Loaded info from ../../../output/results/dev_CRY_onspill-LH_aw_noCRV/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                       Cut      Group  Events Passing  Absolute [%]  \
# 0                 No cuts        NaN         2610933           100
# 1           has_trk_front  Preselect         2558235        97.982
# 2             has_trk_mid  Preselect         2558229        97.981
# 3        is_reco_electron  Preselect         2478081        94.912
# 4       one_reco_electron  Preselect         2050975        78.553
# 5           is_downstream  Preselect         1127230        43.173
# 6       is_truth_electron  Preselect          320790        12.286
# 7            good_trkqual    Tracker          253943         9.726
# 8               within_t0    Tracker          203324         7.787
# 9            within_t0err    Tracker          188703         7.227
# 10               has_hits    Tracker          186118         7.128
# 11              within_d0    Tracker           53454         2.047
# 12  within_pitch_angle_lo    Tracker           48276         1.849
# 13  within_pitch_angle_hi    Tracker           25564         0.979
# 14      within_lhr_max_hi    Tracker           20678         0.792
# 15        within_wide_win   Momentum           20087         0.769
# 16         within_ext_win   Momentum            3339         0.128
# 17         within_sig_win   Momentum             423         0.016
#
#     Relative [%]                                  Description
# 0            100                         No selection applied
# 1         97.982            Tracks intersect tracker entrance
# 2            100              Tracks intersect tracker middle
# 3         96.867                          Electron track fits
# 4         82.765                    One reco electron / event
# 5         54.961    Has downstream track (p_z > 0 in tracker)
# 6         28.458      Track parents are electrons (truth PID)
# 7         79.162                      Track fit quality > 0.2
# 8         80.067      t0 at tracker mid (640 < t_0 < 1650 ns)
# 9         92.809    Track fit t0 uncertainty (t0err < 0.9 ns)
# 10        98.630                      >20 active tracker hits
# 11        28.720  Distance of closest approach (d_0 < 100 mm)
# 12        90.313       Extrapolated pitch angle (pz/pt > 0.5)
# 13        52.954       Extrapolated pitch angle (pz/pt < 1.0)
# 14        80.887   Loop helix maximum radius (R_max < 680 mm)
# 15        97.142             Wide window (85 < p < 200 MeV/c)
# 16        16.623        Extended window (100 < p < 110 MeV/c)
# 17        12.668      Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Efficiency & rates

# %%
display(results["analysis"])
# Out:
# Window                                                 Inclusive  \
# Generated                                         41,100,000,000
# Selected                                                  20,678
# Unvetoed                                                       0
# Selection Eff [%]                                       5.03e-05
# Selection Eff Err$-$ [%]                               -3.49e-07
# Selection Eff Err$+$ [%]                                3.51e-07
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -0.005
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                         1.13e+04
# Selection Rate 1BB [$\text{day}^{-1}$]                     0.588
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.004
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.004
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.449
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.003
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.003
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            3.24e-05
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            2.47e-05
# Run-1 Livetimes                                          282.943
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                73.082
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -0.505
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0.509
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.004
#
# Window                                                      Wide  \
# Generated                                         41,100,000,000
# Selected                                                  20,087
# Unvetoed                                                       0
# Selection Eff [%]                                       4.89e-05
# Selection Eff Err$-$ [%]                               -3.44e-07
# Selection Eff Err$+$ [%]                                3.46e-07
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -0.005
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                         9.03e+03
# Selection Rate 1BB [$\text{day}^{-1}$]                     0.716
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.005
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.005
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.547
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.004
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.004
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            4.06e-05
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            3.10e-05
# Run-1 Livetimes                                          225.529
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                89.066
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -0.625
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0.629
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.005
#
# Window                                                  Extended  \
# Generated                                         41,100,000,000
# Selected                                                   3,339
# Unvetoed                                                       0
# Selection Eff [%]                                       8.12e-06
# Selection Eff Err$-$ [%]                               -1.39e-07
# Selection Eff Err$+$ [%]                                1.42e-07
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -0.030
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                          946.931
# Selection Rate 1BB [$\text{day}^{-1}$]                     1.135
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.020
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.020
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.867
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.015
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.015
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            3.87e-04
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            2.96e-04
# Run-1 Livetimes                                           23.646
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]               141.208
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -2.430
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          2.473
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.048
#
# Window                                                    Signal
# Generated                                         41,100,000,000
# Selected                                                     423
# Unvetoed                                                       0
# Selection Eff [%]                                       1.03e-06
# Selection Eff Err$-$ [%]                               -4.88e-08
# Selection Eff Err$+$ [%]                                5.13e-08
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -0.236
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                          123.611
# Selection Rate 1BB [$\text{day}^{-1}$]                     1.102
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.053
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.056
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.842
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.041
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.043
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]               0.003
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]               0.002
# Run-1 Livetimes                                            3.087
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]               137.039
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -6.625
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          6.954
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.369

# %% [markdown]
# ### Histograms

# %%
# Setup draw for this cutset
on_spill = "offspill" not in ana_label
draw = Draw(cutset_name=ana_label.split('_')[0], on_spill=on_spill)
# Define image directory
img_dir = f"../../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Load] ✅ Initialised with out_path=test_out
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_onspill-LH_aw_noCRV/h1o_1x3_mom_windows.png

# %%
draw.plot_summary(results["hists"], out_path=f"{img_dir}/h1o_3x3_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_onspill-LH_aw_noCRV/h1o_3x3_summary.png

# %%
draw.plot_mom_summary(results["hists"], out_path=f"{img_dir}/h1o_2x2_mom_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_onspill-LH_aw_noCRV/h1o_2x2_mom_summary.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_z.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_onspill-LH_aw_noCRV/h1o_crv_z.png

# %%
draw.draw_cosmic_parents_from_array(results["events"], out_path=f"{img_dir}/h1_cosmic_parents.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_onspill-LH_aw_noCRV/h1_cosmic_parents.png

# %% [markdown]
# ### Background event info

# %%
# print(results["event_info"])

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = 10) # len(results["events"]))
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [pyprint] ⭐️ Printing 10 event(s)...
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 5567
# evt.event: 274654
# crv.crvcoincs.time: [798]
# crv.crvcoincs.timeStart: [815]
# crv.crvcoincs.timeEnd: [902]
# crv.crvcoincs.nHits: [16]
# crv.crvcoincs.pos.fCoordinates.fZ: [-6.39e+03]
# dev.at_trk_front: [[False, False, True, False, False, False], ..., [False, False, ..., False]]
# dev.has_trk_front: [True, True, True, True]
# dev.at_trk_mid: [[False, True, False, False, False, False], ..., [False, True, ..., False]]
# dev.has_trk_mid: [True, True, True, True]
# dev.is_reco_electron: [True, False, False, False]
# dev.one_reco_electron: [True, True, True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, False, True, False]
# dev.all_downstream: [False, False, False, False]
# dev.all_downstream_per_event: False
# dev.has_trk_parent_electron: [True, True, True, True]
# dev.good_trkqual: [True, False, True, False]
# dev.within_t0: [True, True, True, True]
# dev.within_t0err: [True, True, True, True]
# dev.has_hits: [True, True, True, True]
# dev.within_d0: [True, True, True, True]
# dev.pitch_angle: [[0.855, 0.939, 0.906, 0.968, 0.141, 0.494], ..., [-0.852, -0.942, ..., -0.334]]
# dev.within_pitch_angle_lo: [True, False, True, False]
# dev.within_pitch_angle_hi: [True, True, True, True]
# dev.within_lhr_max_lo: [True, True, True, True]
# dev.within_lhr_max_hi: [True, True, True, True]
# dev.veto_condition: [True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[853], [], [], []]
# dev.coinc_times: [798]
# dev.dT_idx: [0]
# dev.dT: [54.7]
# dev.min_dT: [54.7]
# dev.min_dT_idx: [0]
# dev.cent_dT: [54.7]
# dev.cent_dT_idx: [0]
# dev.mom_mag: [[161, 161, 161, 160, 161, 161], [...], ..., [160, 160, 160, 161, 160, 160]]
# dev.within_wide_win: [True, True, True, True]
# dev.within_ext_win: [False, False, False, False]
# dev.within_sig_win: [False, False, False, False]
# dev.preselect: [True, False, False, False]
# dev.select: [True, False, False, False]
# trk.trk.nactive: [69]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.97]
# trkfit.trksegs.mom.fCoordinates.fX: [[-122, 16.5, 116, -114, -140, 63.1]]
# trkfit.trksegs.mom.fCoordinates.fY: [[-0.615, -116, 28.6, 14.5, 76.6, 130]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[105, 110, 108, 111, 22.5, 71.4]]
# trkfit.trksegs.pos.fCoordinates.fX: [[215, -137, 337, 297, 313, 471]]
# trkfit.trksegs.pos.fCoordinates.fY: [[210, -215, -530, 217, 133, -262]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-2.75e+03, 10.1, -1.63e+03, 1.64e+03, -5.97e+03, -4.57e+03]]
# trkfit.trksegs.time: [[839, 853, 845, 861, 811, 828]]
# trkfit.trksegs.dmom: [[-0.143, 0, 0, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.0976, 0.0939, 0.096, 0.0928, 0.0976, 0.0976]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, False]]
# trkfit.trksegs.sid: [[90, 1, 0, 2, 96, 95]]
# trkfit.trksegs.sindex: [[0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[638, 678, 680, 685, 548, 744]]
# trkfit.trksegpars_lh.d0: [[73.1, 93.5, 89.7, 86.9, 18, 125]]
# trkfit.trksegpars_lh.tanDip: [[0.807, 0.939, 0.898, 0.968, 0.143, 0.437]]
# trkfit.trksegpars_lh.rad: [[356, 386, 385, 386, 283, 310]]
# trkfit.trksegpars_lh.lam: [[295, 363, 349, 374, 37.5, 152]]
# trkfit.trksegpars_lh.cx: [[261, 244, 245, 249, 253, 365]]
# trkfit.trksegpars_lh.cy: [[-108, -160, -164, -167, -78.6, -236]]
# trkfit.trksegpars_lh.phi0: [[-0.117, -1.46, -1.37, -1.37, -1.94, -0.311]]
# trkfit.trksegpars_lh.t0: [[853, 853, 853, 853, 962, 863]]
# trkfit.trksegpars_lh.raderr: [[1.45, 0.134, 0.781, 0.822, 0.245, 1.06]]
# trkfit.trksegpars_lh.lamerr: [[1.74, 0.378, 0.843, 0.851, 1.36, 2.14]]
# trkfit.trksegpars_lh.cxerr: [[3.93, 0.572, 0.992, 0.972, 2.14, 4.65]]
# trkfit.trksegpars_lh.cyerr: [[8.51, 0.337, 0.83, 0.784, 4.24, 1.93]]
# trkfit.trksegpars_lh.phi0err: [[0.0324, 0.000824, 0.0107, 0.00925, 3.72, 0.128]]
# trkfit.trksegpars_lh.t0err: [[0.369, 0.411, 0.411, 0.411, 3.46, 0.25]]
# trkmc.trkmcsim.valid: [[True, True, True, True]]
# trkmc.trkmcsim.id: [[29, 0, 32, 0]]
# trkmc.trkmcsim.nhits: [[68, -1, 1, -1]]
# trkmc.trkmcsim.nactive: [[68, -1, 1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, 1, -1]]
# trkmc.trkmcsim.pdg: [[11, -13, 11, -13]]
# trkmc.trkmcsim.startCode: [[31, 56, 17, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 17, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, -1, 38]]
# trkmc.trkmcsim.time: [[5.67e+04, 5.67e+04, 5.68e+04, 5.67e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2, 3]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[302, 5.02e+03, 0.0119, 5.02e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-389, -5.43e+03, -0.076, -5.43e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[59.9, 648, 0.108, 648]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[-254, -1.48e+04, 629, -1.48e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[-333, 1.54e+04, -165, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-5.95e+03, -8.01e+03, -1.17e+03, -8.01e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[-0, 3.63e+03, -0, 3.63e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[-0, -3.88e+03, 0, -3.88e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, 721, 0, 721]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-36.9, -1.13e+03, 629, -1.13e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[-417, 684, -165, 684]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[2.55e+03, -6.15e+03, -1.17e+03, -6.15e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, 0, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, 0, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 5682
# evt.event: 142983
# crv.crvcoincs.time: [732]
# crv.crvcoincs.timeStart: [760]
# crv.crvcoincs.timeEnd: [835]
# crv.crvcoincs.nHits: [16]
# crv.crvcoincs.pos.fCoordinates.fZ: [-4.07e+03]
# dev.at_trk_front: [[False, False, False, True, False, False], ..., [False, False, ..., False]]
# dev.has_trk_front: [True, True, True, True]
# dev.at_trk_mid: [[False, False, True, False, False, False], ..., [False, False, ..., False]]
# dev.has_trk_mid: [True, True, True, True]
# dev.is_reco_electron: [True, False, False, False]
# dev.one_reco_electron: [True, True, True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, False, True, False]
# dev.all_downstream: [False, False, False, False]
# dev.all_downstream_per_event: False
# dev.has_trk_parent_electron: [True, True, True, True]
# dev.good_trkqual: [True, False, True, False]
# dev.within_t0: [True, True, True, True]
# dev.within_t0err: [True, True, True, True]
# dev.has_hits: [True, True, True, True]
# dev.within_d0: [True, True, True, True]
# dev.pitch_angle: [[0.383, 0.373, 0.647, 0.622, 0.618, 0.3], ..., [-0.368, -0.358, ..., -0.292]]
# dev.within_pitch_angle_lo: [True, False, True, False]
# dev.within_pitch_angle_hi: [True, True, True, True]
# dev.within_lhr_max_lo: [True, True, True, True]
# dev.within_lhr_max_hi: [True, False, True, False]
# dev.veto_condition: [True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[766], [], [], []]
# dev.coinc_times: [732]
# dev.dT_idx: [0]
# dev.dT: [33.9]
# dev.min_dT: [33.9]
# dev.min_dT_idx: [0]
# dev.cent_dT: [33.9]
# dev.cent_dT_idx: [0]
# dev.mom_mag: [[127, 127, 126, 127, 126, 127], ..., [127, 127, 128, 127, 129, 126, 126]]
# dev.within_wide_win: [True, True, True, True]
# dev.within_ext_win: [False, False, False, False]
# dev.within_sig_win: [False, False, False, False]
# dev.preselect: [True, False, False, False]
# dev.select: [True, False, False, False]
# trk.trk.nactive: [72]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.685]
# trkfit.trksegs.mom.fCoordinates.fX: [[-64.1, 117, -94.8, -94.6, 2.25, -5.89]]
# trkfit.trksegs.mom.fCoordinates.fY: [[99.6, 21.8, -47.4, 51.4, -107, -121]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[45.3, 44.3, 68.5, 66.9, 66, 36.5]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-3.11, -218, -455, -126, -650, -605]]
# trkfit.trksegs.pos.fCoordinates.fY: [[300, -206, 444, 428, 127, 134]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-2.87e+03, -3.12e+03, 10.1, -1.63e+03, 1.64e+03, -3.32e+03]]
# trkfit.trksegs.time: [[748, 745, 766, 756, 776, 743]]
# trkfit.trksegs.dmom: [[-0.0966, -0.0971, 0, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.0947, 0.0955, 0.0915, 0.0939, 0.0907, 0.0955]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, False]]
# trkfit.trksegs.sid: [[90, 90, 1, 0, 2, 95]]
# trkfit.trksegs.sindex: [[0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[663, 663, 675, 668, 679, 859]]
# trkfit.trksegpars_lh.d0: [[4.06, 2.11, 22.3, 23.8, 38.6, 191]]
# trkfit.trksegpars_lh.tanDip: [[0.419, 0.368, 0.647, 0.627, 0.618, 0.32]]
# trkfit.trksegpars_lh.rad: [[333, 330, 349, 346, 359, 334]]
# trkfit.trksegpars_lh.lam: [[133, 117, 227, 217, 222, 96.3]]
# trkfit.trksegpars_lh.cx: [[-283, -324, -299, -295, -290, -497]]
# trkfit.trksegpars_lh.cy: [[168, 75.7, 132, 129, 136, 170]]
# trkfit.trksegpars_lh.phi0: [[-1.47, 1.64, -2.73, -2.4, -2.64, 0.931]]
# trkfit.trksegpars_lh.t0: [[773, 776, 766, 766, 766, 782]]
# trkfit.trksegpars_lh.raderr: [[0.606, 0.619, 0.332, 0.765, 0.883, 0.788]]
# trkfit.trksegpars_lh.lamerr: [[1.38, 1.6, 0.281, 1.15, 1.27, 2.55]]
# trkfit.trksegpars_lh.cxerr: [[1.25, 1.88, 0.383, 1.12, 1.4, 4.07]]
# trkfit.trksegpars_lh.cyerr: [[7.12, 3.82, 0.311, 0.728, 1.19, 5.71]]
# trkfit.trksegpars_lh.phi0err: [[0.22, 0.342, 0.001, 0.0357, 0.0377, 0.662]]
# trkfit.trksegpars_lh.t0err: [[0.515, 0.604, 0.391, 0.392, 0.395, 0.595]]
# trkmc.trkmcsim.valid: [[True, True, True]]
# trkmc.trkmcsim.id: [[10, 0, 0]]
# trkmc.trkmcsim.nhits: [[82, -1, -1]]
# trkmc.trkmcsim.nactive: [[72, -1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, -1]]
# trkmc.trkmcsim.pdg: [[11, 13, 13]]
# trkmc.trkmcsim.startCode: [[31, 56, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, 38]]
# trkmc.trkmcsim.time: [[6.01e+04, 6e+04, 6e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[-21, -2.63e+03, -2.63e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-137, -9.09e+03, -9.09e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[42, 2.48e+03, 2.48e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[-608, 3.73e+03, 3.73e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[170, 1.54e+04, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-3.36e+03, -7.53e+03, -7.53e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[-0, -2.29e+03, -2.29e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[0, -8.26e+03, -8.26e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, 2.27e+03, 2.27e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-628, -322, -322]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[16.1, 1.26e+03, 1.26e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.73e+03, -3.67e+03, -3.67e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 5682
# evt.event: 281017
# crv.crvcoincs.time: [693, 667]
# crv.crvcoincs.timeStart: [705, 680]
# crv.crvcoincs.timeEnd: [842, 830]
# crv.crvcoincs.nHits: [23, 17]
# crv.crvcoincs.pos.fCoordinates.fZ: [-5.78e+03, -6.19e+03]
# dev.at_trk_front: [[False, False, False, False, False, ..., False, False, False, False], ...]
# dev.has_trk_front: [True, True, True, True]
# dev.at_trk_mid: [[False, False, False, False, True, ..., False, False, False, False], ...]
# dev.has_trk_mid: [True, True, True, True]
# dev.is_reco_electron: [True, False, False, False]
# dev.one_reco_electron: [True, True, True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, False, True, False]
# dev.all_downstream: [False, False, False, False]
# dev.all_downstream_per_event: False
# dev.has_trk_parent_electron: [True, True, True, True]
# dev.good_trkqual: [True, True, True, False]
# dev.within_t0: [True, True, True, True]
# dev.within_t0err: [True, False, True, False]
# dev.has_hits: [True, True, True, True]
# dev.within_d0: [True, True, True, True]
# dev.pitch_angle: [[0.782, 0.59, 0.59, 0.589, 0.994, 0.978, 1.02, 0.217, 0.589, 0.591], ...]
# dev.within_pitch_angle_lo: [True, False, True, False]
# dev.within_pitch_angle_hi: [True, True, True, True]
# dev.within_lhr_max_lo: [True, True, True, True]
# dev.within_lhr_max_hi: [True, True, True, True]
# dev.veto_condition: [True, True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[721], [], [], []]
# dev.coinc_times: [693, 667]
# dev.dT_idx: [0, 1]
# dev.dT: [28, 54.3]
# dev.min_dT: [28]
# dev.min_dT_idx: [0]
# dev.cent_dT: [54.3]
# dev.cent_dT_idx: [1]
# dev.mom_mag: [[112, 112, 113, 113, 112, 112, 112, 113, 113, 112], ..., [112, 112, ..., 111]]
# dev.within_wide_win: [True, True, True, True]
# dev.within_ext_win: [False, False, False, False]
# dev.within_sig_win: [False, False, False, False]
# dev.preselect: [True, False, False, False]
# dev.select: [True, False, False, False]
]
# trkmc.trkmcsim.valid: [[True, True, True]]
# trkmc.trkmcsim.id: [[10, 0, 0]]
# trkmc.trkmcsim.nhits: [[35, -1, -1]]
# trkmc.trkmcsim.nactive: [[35, -1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, -1]]
# trkmc.trkmcsim.pdg: [[11, -13, -13]]
# trkmc.trkmcsim.startCode: [[31, 56, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, 38]]
# trkmc.trkmcsim.time: [[7.7e+04, 7.69e+04, 7.69e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[-89.9, -4e+03, -4e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-69, -4.03e+03, -4.03e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[14.8, 661, 661]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[16.3, 1.46e+04, 1.46e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[286, 1.54e+04, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-5.94e+03, -8.12e+03, -8.12e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[0, -1.46e+03, -1.46e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[0, -1.74e+03, -1.74e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, 158, 158]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[405, 776, 776]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[-4.54, 1.08e+03, 1.08e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.83e+03, -6e+03, -6e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 5807
# evt.event: 254505
# crv.crvcoincs.time: [1.2e+03]
# crv.crvcoincs.timeStart: [1.21e+03]
# crv.crvcoincs.timeEnd: [1.33e+03]
# crv.crvcoincs.nHits: [21]
# crv.crvcoincs.pos.fCoordinates.fZ: [-5.99e+03]
# dev.at_trk_front: [[False, False, False, False, True, ..., False, False, False, False], ...]
# dev.has_trk_front: [True, True, True, True]
# dev.at_trk_mid: [[False, False, False, True, False, ..., False, False, False, False], ...]
# dev.has_trk_mid: [True, True, True, True]
# dev.is_reco_electron: [True, False, False, False]
# dev.one_reco_electron: [True, True, True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, False, True, False]
# dev.all_downstream: [False, False, False, False]
# dev.all_downstream_per_event: False
# dev.has_trk_parent_electron: [True, True, True, True]
# dev.good_trkqual: [True, True, True, False]
# dev.within_t0: [True, True, True, True]
# dev.within_t0err: [True, True, True, True]
# dev.has_hits: [True, True, True, True]
# dev.within_d0: [True, True, True, True]
# dev.pitch_angle: [[0.841, 0.478, 0.479, 0.868, 0.853, ..., 0.151, 0.284, 0.479, 0.478], ...]
# dev.within_pitch_angle_lo: [True, False, True, False]
# dev.within_pitch_angle_hi: [True, True, True, True]
# dev.within_lhr_max_lo: [True, True, True, True]
# dev.within_lhr_max_hi: [True, True, True, True]
# dev.veto_condition: [True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[1.23e+03], [], [], []]
# dev.coinc_times: [1.2e+03]
# dev.dT_idx: [0]
# dev.dT: [38.3]
# dev.min_dT: [38.3]
# dev.min_dT_idx: [0]
# dev.cent_dT: [38.3]
# dev.cent_dT_idx: [0]
# dev.mom_mag: [[131, 131, 131, 131, 131, 130, 131, 131, 131, 131], ..., [130, 130, ..., 130]]
# dev.within_wide_win: [True, True, True, True]
# dev.within_ext_win: [False, False, False, False]
# dev.within_sig_win: [False, False, False, False]
# dev.preselect: [True, False, False, False]
# dev.select: [True, False, False, False]
# trk.trk.nactive: [59]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.99]
# trkfit.trksegs.mom.fCoordinates.fX: [[89.5, -8.58, 34.5, -97.2, -83.7, -90.6, 118, 14.7, 45.3, -20.1]]
# trkfit.trksegs.mom.fCoordinates.fY: [[45.4, 118, 113, -17.2, -54.1, 37.7, -54.5, -125, 109, 117]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[84.4, 56.6, 56.7, 85.6, 85, 85.6, 19.6, 35.9, 56.7, 56.6]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-183, -15.5, -25.7, -401, -514, -224, -339, -483, -34, -18.5]]
# trkfit.trksegs.pos.fCoordinates.fY: [[-238, 47.9, -43.8, 353, 300, 339, -188, -4.07, -66.9, 72.7]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-2.49e+03, -4.57e+03, -4.61e+03, 10.1, ..., -5.44e+03, -4.62e+03, -4.55e+03]]
# trkfit.trksegs.time: [[1.22e+03, 1.21e+03, 1.21e+03, 1.23e+03, ..., 1.2e+03, 1.21e+03, 1.21e+03]]
# trkfit.trksegs.dmom: [[-0.111, -0.0822, -0.0821, 0, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.0776, 0.0784, 0.0791, 0.0746, 0.0764, ..., 0.0791, 0.0791, 0.0791, 0.0776]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, False, False, False, False, False]]
# trkfit.trksegs.sid: [[90, 104, 104, 1, 0, 2, 96, 95, 103, 103]]
# trkfit.trksegs.sindex: [[0, 6, 4, 0, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[671, 533, 532, 671, 669, 678, 553, 701, 535, 535]]
# trkfit.trksegpars_lh.d0: [[57.9, 27.2, 27, 21.6, 29.4, 19.8, 90.5, 230, 30.7, 28.9]]
# trkfit.trksegpars_lh.tanDip: [[0.761, 0.479, 0.476, 0.867, 0.851, 0.872, 0.145, 0.304, 0.472, 0.48]]
# trkfit.trksegpars_lh.rad: [[306, 253, 252, 325, 320, 329, 231, 235, 252, 253]]
# trkfit.trksegpars_lh.lam: [[246, 122, 120, 283, 275, 288, 32.8, 65.9, 119, 123]]
# trkfit.trksegpars_lh.cx: [[-364, -276, -279, -345, -348, -347, -321, -465, -283, -277]]
# trkfit.trksegpars_lh.cy: [[-17, 48.2, 13.1, 33.8, 33.6, 34.7, -20.8, 17.7, 1.86, 54]]
# trkfit.trksegpars_lh.phi0: [[-1.96, 1.28, 2.15, -3.01, -2.92, -2.94, -0.883, -0.96, 2.45, 1.15]]
# trkfit.trksegpars_lh.t0: [[1.23e+03, 1.24e+03, 1.24e+03, 1.23e+03, ..., 1.27e+03, 1.24e+03, 1.24e+03]]
# trkfit.trksegpars_lh.raderr: [[0.996, 0.75, 0.91, 0.33, 0.69, 0.735, 0.286, 0.506, 0.903, 0.507]]
# trkfit.trksegpars_lh.lamerr: [[1.23, 1.52, 1.89, 0.303, 0.781, 0.829, 1.78, 1.73, 1.89, 0.996]]
# trkfit.trksegpars_lh.cxerr: [[1.53, 1.41, 1.56, 0.46, 0.84, 1.11, 3.99, 5.27, 1.59, 1.29]]
# trkfit.trksegpars_lh.cyerr: [[6.75, 5.68, 6.72, 0.261, 0.985, 0.674, 6.75, 6.47, 7, 5.38]]
# trkfit.trksegpars_lh.phi0err: [[0.041, 0.422, 0.573, 0.00123, 0.0164, 0.00942, 9.2, 1.85, 0.582, 0.234]]
# trkfit.trksegpars_lh.t0err: [[0.396, 0.531, 0.64, 0.415, 0.417, 0.416, 7.25, 1.56, 0.646, 0.417]]
# trkmc.trkmcsim.valid: [[True, True, True]]
# trkmc.trkmcsim.id: [[9, 0, 0]]
# trkmc.trkmcsim.nhits: [[59, -1, -1]]
# trkmc.trkmcsim.nactive: [[59, -1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, -1]]
# trkmc.trkmcsim.pdg: [[11, 13, 13]]
# trkmc.trkmcsim.startCode: [[31, 56, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, 38]]
# trkmc.trkmcsim.time: [[9.95e+04, 9.95e+04, 9.95e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[6.2, 1.33e+03, 1.33e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-128, -1.54e+04, -1.54e+04]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[34.3, 3.18e+03, 3.18e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[-484, -1.83e+03, -1.83e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[10.9, 1.54e+04, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-5.44e+03, -8.59e+03, -8.59e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[0, 1.22e+03, 1.22e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[-0, -1.44e+04, -1.44e+04]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, 2.94e+03, 2.94e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-360, -596, -596]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[363, 1.16e+03, 1.16e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.74e+03, -5.67e+03, -5.67e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 5940
# evt.event: 396732
# crv.crvcoincs.time: [826]
# crv.crvcoincs.timeStart: [841]
# crv.crvcoincs.timeEnd: [954]
# crv.crvcoincs.nHits: [21]
# crv.crvcoincs.pos.fCoordinates.fZ: [-2.58e+03]
# dev.at_trk_front: [[False, False, False, False, False, True, False], [False, ..., False]]
# dev.has_trk_front: [True, True]
# dev.at_trk_mid: [[False, False, False, False, True, False, False], [False, ..., False]]
# dev.has_trk_mid: [True, True]
# dev.is_reco_electron: [True, False]
# dev.one_reco_electron: [True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, True]
# dev.all_downstream: [True, True]
# dev.all_downstream_per_event: True
# dev.has_trk_parent_electron: [True, True]
# dev.good_trkqual: [True, False]
# dev.within_t0: [True, True]
# dev.within_t0err: [True, False]
# dev.has_hits: [True, True]
# dev.within_d0: [True, True]
# dev.pitch_angle: [[0.522, 0.381, 0.373, 0.298, 0.568, 0.552, 0.579], [0.504, ..., 0.593]]
# dev.within_pitch_angle_lo: [True, True]
# dev.within_pitch_angle_hi: [True, True]
# dev.within_lhr_max_lo: [True, True]
# dev.within_lhr_max_hi: [True, True]
# dev.veto_condition: [True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[845], []]
# dev.coinc_times: [826]
# dev.dT_idx: [0]
# dev.dT: [18.7]
# dev.min_dT: [18.7]
# dev.min_dT_idx: [0]
# dev.cent_dT: [18.7]
# dev.cent_dT_idx: [0]
# dev.mom_mag: [[82.8, 82.9, 83, 83.1, 82.4, 82.7, 82.1], [84.2, 84.6, ..., 83.8, 81.8]]
# dev.within_wide_win: [False, False]
# dev.within_ext_win: [False, False]
# dev.within_sig_win: [False, False]
# dev.preselect: [True, False]
# dev.select: [True, False]
# trk.trk.nactive: [32]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.533]
# trkfit.trksegs.mom.fCoordinates.fX: [[72.9, -73, 77.6, -76, 65.1, 67.7, 33]]
# trkfit.trksegs.mom.fCoordinates.fY: [[8.77, 26.1, 5.26, 23.8, -29.8, -25.8, -62.9]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[38.3, 29.5, 29, 23.7, 40.7, 40, 41.1]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-230, -179, -233, -181, -369, -349, -487]]
# trkfit.trksegs.pos.fCoordinates.fY: [[-193, 241, -188, 240, -187, -189, -86.4]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-2.35e+03, -2.71e+03, -2.94e+03, -3.2e+03, 10.1, -1.63e+03, 1.64e+03]]
# trkfit.trksegs.time: [[829, 826, 823, 821, 845, 834, 856]]
# trkfit.trksegs.dmom: [[-0.103, -0.0985, -0.0998, -0.0982, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.123, 0.123, 0.124, 0.125, 0.119, 0.122, 0.116]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, False, False]]
# trkfit.trksegs.sid: [[90, 90, 90, 90, 1, 0, 2]]
# trkfit.trksegs.sindex: [[0, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[527, 519, 509, 514, 509, 509, 512]]
# trkfit.trksegpars_lh.d0: [[71.4, 74.8, 69.5, 80.8, 36, 41.8, 34.4]]
# trkfit.trksegpars_lh.tanDip: [[0.508, 0.38, 0.369, 0.339, 0.567, 0.553, 0.581]]
# trkfit.trksegpars_lh.rad: [[228, 222, 220, 216, 237, 234, 239]]
# trkfit.trksegpars_lh.lam: [[113, 89.1, 78.4, 68.4, 134, 128, 138]]
# trkfit.trksegpars_lh.cx: [[-299, -287, -289, -285, -271, -274, -272]]
# trkfit.trksegpars_lh.cy: [[-2.05, 77, -1.7, 85.9, 28.5, 24.9, 26.6]]
# trkfit.trksegpars_lh.phi0: [[1.91, 1.72, -0.218, -0.821, -0.512, -0.2, -0.393]]
# trkfit.trksegpars_lh.t0: [[846, 850, 853, 856, 845, 845, 845]]
# trkfit.trksegpars_lh.raderr: [[0.863, 0.741, 0.714, 0.798, 0.482, 0.54, 0.66]]
# trkfit.trksegpars_lh.lamerr: [[1.59, 1.65, 1.78, 2.27, 0.102, 0.818, 0.827]]
# trkfit.trksegpars_lh.cxerr: [[1.28, 1.52, 1.87, 2.13, 0.537, 0.739, 1.33]]
# trkfit.trksegpars_lh.cyerr: [[4.1, 2.83, 1.81, 2.1, 0.286, 1.42, 1.02]]
# trkfit.trksegpars_lh.phi0err: [[0.213, 0.421, 0.679, 1.19, 0.00158, 0.0493, 0.0651]]
# trkfit.trksegpars_lh.t0err: [[0.347, 0.458, 0.624, 0.805, 0.446, 0.445, 0.451]]
# trkmc.trkmcsim.valid: [[True, True, True, True]]
# trkmc.trkmcsim.id: [[3, 0, 8, 0]]
# trkmc.trkmcsim.nhits: [[28, -1, 1, -1]]
# trkmc.trkmcsim.nactive: [[28, -1, 1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, 2, -1]]
# trkmc.trkmcsim.pdg: [[11, -13, 11, -13]]
# trkmc.trkmcsim.startCode: [[31, 56, 17, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 17, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, -1, 38]]
# trkmc.trkmcsim.time: [[6.86e+04, 6.86e+04, 6.87e+04, 6.86e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2, 3]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[-8.91, -1.76e+03, 0.0744, -1.76e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-71.7, -8.32e+03, 0.029, -8.32e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[40.3, 5.05e+03, 0.24, 5.05e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[-502, 2.76e+03, -447, 2.76e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[60.1, 1.54e+04, 191, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-989, -1.03e+04, 1.47e+03, -1.03e+04]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[-0, -1.62e+03, 0, -1.62e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[0, -7.36e+03, 0, -7.36e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, 4.42e+03, -0, 4.42e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-401, -222, -447, -222]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[-183, 1.28e+03, 191, 1.28e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.72e+03, -1.73e+03, 1.49e+03, -1.73e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, 0, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, 0, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 5966
# evt.event: 135044
# crv.crvcoincs.time: [1.4e+03]
# crv.crvcoincs.timeStart: [1.41e+03]
# crv.crvcoincs.timeEnd: [1.51e+03]
# crv.crvcoincs.nHits: [20]
# crv.crvcoincs.pos.fCoordinates.fZ: [-5.14e+03]
# dev.at_trk_front: [[False, False, False, False, False, ..., False, False, False, False], ...]
# dev.has_trk_front: [True, True, True, True]
# dev.at_trk_mid: [[False, False, False, False, False, ..., False, False, False, False], ...]
# dev.has_trk_mid: [True, True, True, True]
# dev.is_reco_electron: [True, False, False, False]
# dev.one_reco_electron: [True, True, True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, False, True, False]
# dev.all_downstream: [False, False, False, False]
# dev.all_downstream_per_event: False
# dev.has_trk_parent_electron: [True, True, True, True]
# dev.good_trkqual: [True, False, True, False]
# dev.within_t0: [True, True, True, True]
# dev.within_t0err: [True, True, True, True]
# dev.has_hits: [True, True, True, True]
# dev.within_d0: [True, True, True, True]
# dev.pitch_angle: [[0.636, 0.445, 0.446, -0.369, -0.368, ..., -0.368, -0.369, 0.446, 0.444], ...]
# dev.within_pitch_angle_lo: [True, False, True, False]
# dev.within_pitch_angle_hi: [True, True, True, True]
# dev.within_lhr_max_lo: [True, True, True, True]
# dev.within_lhr_max_hi: [True, False, True, False]
# dev.veto_condition: [True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[1.43e+03], [], [], []]
# dev.coinc_times: [1.4e+03]
# dev.dT_idx: [0]
# dev.dT: [29.6]
# dev.min_dT: [29.6]
# dev.min_dT_idx: [0]
# dev.cent_dT: [29.6]
# dev.cent_dT_idx: [0]
# dev.mom_mag: [[133, 133, 133, 133, 133, 132, 133, 131, 133, 133, 133, 133, 133], ..., [...]]
# dev.within_wide_win: [True, True, True, True]
# dev.within_ext_win: [False, False, False, False]
# dev.within_sig_win: [False, False, False, False]
# dev.preselect: [True, False, False, False]
# dev.select: [True, False, False, False]
# trk.trk.nactive: [76]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.98]
# trkfit.trksegs.mom.fCoordinates.fX: [[-111, -63.2, -43.7, -70.9, -46.3, -17.5, ..., 90.1, -28.7, -83, -27.5, -78.7]]
# trkfit.trksegs.mom.fCoordinates.fY: [[17, 103, 113, 103, 116, 95.4, 66.8, 74.2, -72.9, 122, 92.9, 118, 92.2]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[71.2, 53.9, 54.1, -46, -46, 89.5, ..., 91, 64.5, -45.9, -46, 54.1, 53.9]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-258, -36.3, -14.2, -41.3, -12.9, ..., -462, -0.855, -61.9, -2.9, -62.1]]
# trkfit.trksegs.pos.fCoordinates.fY: [[152, 6.52, -38.2, 16.1, -36.9, -102, ..., -360, -375, -75, 42.3, -74.9, 42.1]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-3.04e+03, -4.19e+03, -4.21e+03, ..., -4.56e+03, -4.23e+03, -4.17e+03]]
# trkfit.trksegs.time: [[1.41e+03, 1.41e+03, 1.41e+03, 1.37e+03, ..., 1.37e+03, 1.41e+03, 1.41e+03]]
# trkfit.trksegs.dmom: [[-0.0976, -0.0876, -0.0875, -0.104, -0.104, 0, 0, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.075, 0.0759, 0.0768, 0.074, 0.0752, ..., 0.0752, 0.0727, 0.0768, 0.075]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True, ..., True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, ..., False, False, False, False, False]]
# trkfit.trksegs.sid: [[90, 104, 104, 104, 104, 1, 0, 2, 95, 103, 103, 103, 103]]
# trkfit.trksegs.sindex: [[0, 23, 22, 7, 8, 0, 0, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[679, 596, 596, 578, 579, 682, 675, 682, 773, 583, 580, 598, 600]]
# trkfit.trksegpars_lh.d0: [[62.2, 41.9, 42.6, 41, 41, 42.1, 41.2, 43.3, 197, 43.9, 44, 45.3, 45.2]]
# trkfit.trksegpars_lh.tanDip: [[0.68, 0.446, 0.438, -0.361, -0.367, ..., 0.488, -0.368, -0.355, 0.432, 0.451]]
# trkfit.trksegpars_lh.rad: [[308, 277, 277, 268, 269, 320, 317, 320, 288, 269, 268, 276, 278]]
# trkfit.trksegpars_lh.lam: [[203, 124, 122, -98.2, -99.8, 295, 285, 305, 157, -101, -97.1, 121, 125]]
# trkfit.trksegpars_lh.cx: [[-347, -288, -280, -279, -270, -325, ..., -327, -414, -267, -287, -276, -298]]
# trkfit.trksegpars_lh.cy: [[-128, -138, -154, -133, -152, -159, ..., -158, -252, -165, -123, -166, -124]]
# trkfit.trksegpars_lh.phi0: [[-0.905, -1.76, -1.33, -0.133, 0.605, ..., -2.33, 1.07, -0.645, -1.02, -2.19]]
# trkfit.trksegpars_lh.t0: [[1.43e+03, 1.44e+03, 1.44e+03, 1.33e+03, ..., 1.33e+03, 1.44e+03, 1.44e+03]]
# trkfit.trksegpars_lh.raderr: [[0.794, 0.797, 0.969, 0.935, 1.07, ..., 0.848, 1.09, 0.785, 0.961, 0.561]]
# trkfit.trksegpars_lh.lamerr: [[1.18, 1.75, 2.16, 2.53, 2.87, 0.395, ..., 1.54, 2.88, 2.13, 2.16, 1.19]]
# trkfit.trksegpars_lh.cxerr: [[6.52, 5.57, 5.42, 9.46, 9.64, 0.632, ..., 1.04, 10.1, 9.71, 9.29, 5.33, 5.78]]
# trkfit.trksegpars_lh.cyerr: [[5.95, 3.03, 2.96, 2.72, 2.89, 0.391, ..., 1.22, 2.82, 2.57, 2.74, 3.14]]
# trkfit.trksegpars_lh.phi0err: [[0.153, 0.567, 0.683, 1.87, 1.93, ..., 0.36, 1.9, 1.79, 0.695, 0.437]]
# trkfit.trksegpars_lh.t0err: [[0.482, 0.757, 0.849, 1.83, 1.89, 0.399, ..., 0.644, 1.87, 1.75, 0.857, 0.661]]
# trkmc.trkmcsim.valid: [[True, True, True]]
# trkmc.trkmcsim.id: [[27, 0, 0]]
# trkmc.trkmcsim.nhits: [[77, -1, -1]]
# trkmc.trkmcsim.nactive: [[76, -1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, -1]]
# trkmc.trkmcsim.pdg: [[11, 13, 13]]
# trkmc.trkmcsim.startCode: [[31, 56, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, 38]]
# trkmc.trkmcsim.time: [[4.55e+04, 4.54e+04, 4.54e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[84.5, 8.32e+03, 8.32e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-88.3, -7.85e+03, -7.85e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[61.9, 5.74e+03, 5.74e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[-494, -1.72e+04, -1.72e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[-348, 1.54e+04, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-3.72e+03, -1.52e+04, -1.52e+04]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[0, 6.53e+03, 6.53e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[0, -6.09e+03, -6.09e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[0, 4.44e+03, 4.44e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-442, -1.28e+03, -1.28e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[130, 362, 362]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[2.45e+03, -4.25e+03, -4.25e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 5986
# evt.event: 124225
# crv.crvcoincs.time: [1.18e+03, 1.2e+03]
# crv.crvcoincs.timeStart: [1.19e+03, 1.22e+03]
# crv.crvcoincs.timeEnd: [1.28e+03, 1.31e+03]
# crv.crvcoincs.nHits: [18, 19]
# crv.crvcoincs.pos.fCoordinates.fZ: [-2.44e+03, -6e+03]
# dev.at_trk_front: [[False, False, False, False, False, ..., False, False, False, False], ...]
# dev.has_trk_front: [True, True, True, True]
# dev.at_trk_mid: [[False, False, False, False, False, ..., False, False, False, False], ...]
# dev.has_trk_mid: [True, True, True, True]
# dev.is_reco_electron: [True, False, False, False]
# dev.one_reco_electron: [True, True, True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, False, True, False]
# dev.all_downstream: [False, False, False, False]
# dev.all_downstream_per_event: False
# dev.has_trk_parent_electron: [True, True, True, True]
# dev.good_trkqual: [True, True, True, False]
# dev.within_t0: [True, True, True, True]
# dev.within_t0err: [True, False, True, False]
# dev.has_hits: [True, True, True, True]
# dev.within_d0: [True, True, True, True]
# dev.pitch_angle: [[0.816, 0.803, 0.518, 0.518, 0.519, ..., 0.949, 0.0994, 0.519, 0.518], ...]
# dev.within_pitch_angle_lo: [True, False, True, False]
# dev.within_pitch_angle_hi: [True, True, True, True]
# dev.within_lhr_max_lo: [True, True, True, True]
# dev.within_lhr_max_hi: [True, True, True, True]
# dev.veto_condition: [True, True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[1.27e+03], [], [], []]
# dev.coinc_times: [1.18e+03, 1.2e+03]
# dev.dT_idx: [0, 1]
# dev.dT: [90.7, 69]
# dev.min_dT: [69]
# dev.min_dT_idx: [1]
# dev.cent_dT: [69]
# dev.cent_dT_idx: [1]
# dev.mom_mag: [[97, 97.1, 97.2, 97.3, 97.3, 96.7, 96.9, 96.4, 97.3, 97.3, 97.1], ..., [...]]
# dev.within_wide_win: [True, True, True, True]
# dev.within_ext_win: [False, False, False, False]
# dev.within_sig_win: [False, False, False, False]
# dev.preselect: [True, False, False, False]
# dev.select: [True, False, False, False]
# trk.trk.nactive: [27]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.93]
# trkfit.trksegs.mom.fCoordinates.fX: [[72.3, -57.6, 62.3, 47.6, 30.5, 45, -50.8, 67.8, -91.4, 15.2, 64.7]]
# trkfit.trksegs.mom.fCoordinates.fY: [[20.5, -49.2, -59.7, -72, -80.9, -55, -51.6, 17.3, 32, -85.1, -57]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[61.3, 60.8, 44.7, 44.8, 44.8, 65.5, 64.3, 66.4, 9.63, 44.8, 44.6]]
# trkfit.trksegs.pos.fCoordinates.fX: [[288, 72.8, 60.1, 32.7, 13.2, 44.9, 59.2, 284, 228, 3.9, 66.1]]
# trkfit.trksegs.pos.fCoordinates.fY: [[-85, 291, -29.8, 3.05, 41.1, -3.36, 307, -82, 262, 74.9, -35.4]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-2.37e+03, -2.86e+03, -4.32e+03, ..., -5.97e+03, -4.38e+03, -4.32e+03]]
# trkfit.trksegs.time: [[1.26e+03, 1.26e+03, 1.25e+03, 1.25e+03, ..., 1.23e+03, 1.25e+03, 1.25e+03]]
# trkfit.trksegs.dmom: [[-0.118, -0.122, -0.0769, -0.0768, -0.0767, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.118, 0.119, 0.119, 0.119, 0.12, ..., 0.117, 0.111, 0.12, 0.12, 0.119]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, ..., False, False, False, False, False]]
# trkfit.trksegs.sid: [[90, 90, 104, 104, 104, 1, 0, 2, 96, 103, 103]]
# trkfit.trksegs.sindex: [[0, 0, 17, 16, 15, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[523, 504, 428, 423, 423, 503, 503, 504, 452, 427, 428]]
# trkfit.trksegpars_lh.d0: [[70.3, 70.1, 43.3, 38.5, 39.3, 34.4, 35.9, 34.2, 108, 43.6, 43.3]]
# trkfit.trksegpars_lh.tanDip: [[0.812, 0.756, 0.524, 0.519, 0.518, ..., 0.889, 0.947, 0.0935, 0.516, 0.524]]
# trkfit.trksegpars_lh.rad: [[226, 217, 192, 192, 192, 235, 233, 235, 172, 191, 192]]
# trkfit.trksegpars_lh.lam: [[192, 169, 101, 99.8, 98.9, 216, 207, 223, 16.2, 97.9, 101]]
# trkfit.trksegpars_lh.cx: [[273, 228, 216, 203, 196, 226, 226, 226, 226, 192, 216]]
# trkfit.trksegpars_lh.cy: [[115, 175, 94.5, 109, 122, 145, 147, 147, 165, 135, 94.4]]
# trkfit.trksegpars_lh.phi0: [[0.0493, 1.86, -1.98, -1.44, -1.05, ..., -0.743, -0.815, -0.639, -0.61, -1.94]]
# trkfit.trksegpars_lh.t0: [[1.27e+03, 1.27e+03, 1.28e+03, 1.28e+03, ..., 1.44e+03, 1.28e+03, 1.28e+03]]
# trkfit.trksegpars_lh.raderr: [[2.35, 2.1, 1.92, 1.99, 2.05, 0.612, 0.871, 0.932, 0.36, 2.03, 1.83]]
# trkfit.trksegpars_lh.lamerr: [[2.74, 2.66, 3.6, 3.76, 3.92, 0.221, 0.936, 0.974, 3.03, 3.92, 3.42]]
# trkfit.trksegpars_lh.cxerr: [[1.81, 5.65, 7.82, 8.37, 8.66, 0.721, 1.25, 1.08, 6.2, 8.8, 7.75]]
# trkfit.trksegpars_lh.cyerr: [[3.83, 3.18, 2.83, 2.58, 2.56, 0.485, 1.07, 0.773, 2.55, 2.36, 2.66]]
# trkfit.trksegpars_lh.phi0err: [[0.115, 0.129, 0.816, 0.973, 1.11, ..., 0.0213, 0.0184, 57.2, 1.14, 0.661]]
# trkfit.trksegpars_lh.t0err: [[0.328, 0.328, 0.447, 0.582, 0.695, ..., 0.463, 0.462, 32.8, 0.707, 0.281]]
# trkmc.trkmcsim.valid: [[True, True, True]]
# trkmc.trkmcsim.id: [[21, 0, 0]]
# trkmc.trkmcsim.nhits: [[27, -1, -1]]
# trkmc.trkmcsim.nactive: [[27, -1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, -1]]
# trkmc.trkmcsim.pdg: [[11, 13, 13]]
# trkmc.trkmcsim.startCode: [[31, 56, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, 38]]
# trkmc.trkmcsim.time: [[9.44e+04, 9.43e+04, 9.43e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[76.3, 4.05e+03, 4.05e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-44.5, -3.08e+03, -3.08e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[-43.8, -3.04e+03, -3.04e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[97.2, -2.02e+04, -2.02e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[-56.1, 1.54e+04, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-4.41e+03, 1.07e+04, 1.07e+04]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[-0, 1.96e+03, 1.96e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[0, -1.58e+03, -1.58e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, -1.48e+03, -1.48e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[381, -1.07e+03, -1.07e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[-33.8, 738, 738]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.74e+03, -3.56e+03, -3.56e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 5989
# evt.event: 7592
# crv.crvcoincs.time: [1.41e+03, 1.42e+03]
# crv.crvcoincs.timeStart: [1.43e+03, 1.43e+03]
# crv.crvcoincs.timeEnd: [1.5e+03, 1.53e+03]
# crv.crvcoincs.nHits: [20, 16]
# crv.crvcoincs.pos.fCoordinates.fZ: [-4.58e+03, -2.24e+03]
# dev.at_trk_front: [[False, False, False, False, True, ..., False, False, False, False], ...]
# dev.has_trk_front: [True, True, True, True]
# dev.at_trk_mid: [[False, False, False, True, False, ..., False, False, False, False], ...]
# dev.has_trk_mid: [True, True, True, True]
# dev.is_reco_electron: [True, False, False, False]
# dev.one_reco_electron: [True, True, True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, False, True, False]
# dev.all_downstream: [False, False, False, False]
# dev.all_downstream_per_event: False
# dev.has_trk_parent_electron: [True, True, True, True]
# dev.good_trkqual: [True, False, True, False]
# dev.within_t0: [True, True, True, True]
# dev.within_t0err: [True, True, True, True]
# dev.has_hits: [True, True, True, True]
# dev.within_d0: [True, True, True, True]
# dev.pitch_angle: [[0.473, 0.462, -0.118, 0.721, 0.678, ..., 0.398, -0.118, 0.0642, 0.0654], ...]
# dev.within_pitch_angle_lo: [True, False, True, False]
# dev.within_pitch_angle_hi: [True, True, True, True]
# dev.within_lhr_max_lo: [True, True, True, True]
# dev.within_lhr_max_hi: [True, False, True, False]
# dev.veto_condition: [True, True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[1.43e+03], [], [], []]
# dev.coinc_times: [1.41e+03, 1.42e+03]
# dev.dT_idx: [0, 1]
# dev.dT: [27.7, 11.5]
# dev.min_dT: [11.5]
# dev.min_dT_idx: [1]
# dev.cent_dT: [27.7]
# dev.cent_dT_idx: [0]
# dev.mom_mag: [[134, 134, 134, 133, 134, 133, 134, 134, 134, 134], ..., [133, 133, ..., 132]]
# dev.within_wide_win: [True, True, True, True]
# dev.within_ext_win: [False, False, False, False]
# dev.within_sig_win: [False, False, False, False]
# dev.preselect: [True, False, False, False]
# dev.select: [True, False, False, False]
# trk.trk.nactive: [65]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.97]
# trkfit.trksegs.mom.fCoordinates.fX: [[-56, -82.7, -133, -105, -111, -104, 103, -127, -133, -127]]
# trkfit.trksegs.mom.fCoordinates.fY: [[-107, 89.2, -15.3, -26, 2.42, -23.6, 70.5, -40.8, 15.1, -43.4]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[57.3, 56.3, -15.8, 78, 75.1, 78.7, 49.5, -15.7, 8.58, 8.75]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-262, 292, -10.7, -19.5, 73.9, -15.2, 234, -72.2, 66.9, -72.6]]
# trkfit.trksegs.pos.fCoordinates.fY: [[-146, -67.4, 33.6, 34.6, 47.4, 37.4, -575, 20.2, 34, 18.7]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-2
+04]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[-612, 1.54e+04, -173, -536, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-3.45e+03, -1.53e+04, 1.27e+03, 989, -1.53e+04]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[-0, 2.64e+03, -0, 0, 2.64e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[-0, -1.44e+03, -0, 0, -1.44e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, 1.23e+03, -0, -0, 1.23e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[123, -1.32e+03, 396, 344, -1.32e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[-555, -43.8, -173, -536, -43.8]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[2.44e+03, -3.98e+03, 1.27e+03, 989, -3.98e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, -1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, -1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, 0, 0, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, 0, 0, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 6042
# evt.event: 243017
# crv.crvcoincs.time: [805, 822]
# crv.crvcoincs.timeStart: [817, 842]
# crv.crvcoincs.timeEnd: [905, 930]
# crv.crvcoincs.nHits: [16, 16]
# crv.crvcoincs.pos.fCoordinates.fZ: [-7.03e+03, -4.78e+03]
# dev.at_trk_front: [[False, False, False, False, False, ..., False, False, False, False], ...]
# dev.has_trk_front: [True, True]
# dev.at_trk_mid: [[False, False, False, False, False, ..., False, False, False, False], ...]
# dev.has_trk_mid: [True, True]
# dev.is_reco_electron: [True, False]
# dev.one_reco_electron: [True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, True]
# dev.all_downstream: [True, True]
# dev.all_downstream_per_event: True
# dev.has_trk_parent_electron: [True, True]
# dev.good_trkqual: [True, True]
# dev.within_t0: [True, True]
# dev.within_t0err: [True, True]
# dev.has_hits: [True, True]
# dev.within_d0: [True, True]
# dev.pitch_angle: [[0.824, 0.813, 0.513, 0.514, 0.515, ..., 1.04, 0.152, 0.515, 0.512], ...]
# dev.within_pitch_angle_lo: [True, True]
# dev.within_pitch_angle_hi: [True, True]
# dev.within_lhr_max_lo: [True, True]
# dev.within_lhr_max_hi: [True, True]
# dev.veto_condition: [True, True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[854], []]
# dev.coinc_times: [805, 822]
# dev.dT_idx: [0, 1]
# dev.dT: [48.8, 31.6]
# dev.min_dT: [31.6]
# dev.min_dT_idx: [1]
# dev.cent_dT: [48.8]
# dev.cent_dT_idx: [0]
# dev.mom_mag: [[90, 90.2, 90.2, 90.3, 90.4, 89.7, 89.9, 89.5, 90.4, 90.4, 90.2], [...]]
# dev.within_wide_win: [True, True]
# dev.within_ext_win: [False, False]
# dev.within_sig_win: [False, False]
# dev.preselect: [True, False]
# dev.select: [True, False]
# trk.trk.nactive: [31]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.974]
# trkfit.trksegs.mom.fCoordinates.fX: [[-64.3, 68.4, 3.02, 22.6, 40.9, -54.4, -30.4, 15.1, -89.3, 44.6, -3.34]]
# trkfit.trksegs.mom.fCoordinates.fY: [[26.4, -14.5, 80.3, 77.1, 69.2, -31.4, 56.1, -60.1, 2.71, 66.8, 80.2]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[57.3, 56.9, 41.2, 41.3, 41.4, 64, 63.4, 64.6, 13.6, 41.4, 41.1]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-167, -272, -35.4, -42.3, -59.5, -363, -72.2, -465, -184, -64.6, -35.4]]
# trkfit.trksegs.pos.fCoordinates.fY: [[249, -126, 52.2, 9.57, -30, 243, 160, 11, 209, -38.1, 66.1]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-2.7e+03, -3.18e+03, -4.46e+03, ..., -5.97e+03, -4.5e+03, -4.45e+03]]
# trkfit.trksegs.time: [[841, 839, 831, 831, 830, 854, 846, 862, 814, 830, 831]]
# trkfit.trksegs.dmom: [[-0.121, -0.125, -0.0775, -0.0774, -0.0772, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.098, 0.0992, 0.0997, 0.1, 0.101, ..., 0.0968, 0.0911, 0.101, 0.101, 0.0992]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, ..., False, False, False, False, False]]
# trkfit.trksegs.sid: [[90, 90, 104, 104, 104, 1, 0, 2, 96, 103, 103]]
# trkfit.trksegs.sindex: [[0, 0, 11, 10, 9, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [
+04]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[-87.2, -83.4, -80.7, -68.4, -67.5, 1.54e+04, -71.1, -71, -112, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-6e+03, -6e+03, -6e+03, -6.01e+03, ..., -6.01e+03, -6.01e+03, 221, -1.58e+04]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[0, 168, 0, 618, -0, 9.36e+03, 0, 138, -0, 9.36e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[0, -106, -0, -386, 0, -6.87e+03, 0, -84.6, 0, -6.87e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, 62.5, -0, 254, 0, 4.23e+03, -0, 51.4, -0, 4.23e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-432, -263, -254, -274, -277, -1.18e+03, -417, -289, -409, -1.18e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[-81.8, -87.2, -57.6, -80.7, -70.3, 561, -115, -71.1, -112, 561]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.74e+03, -6e+03, -5.95e+03, -6e+03, ..., 1.49e+03, -6.01e+03, 221, -6.4e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, -1, -1, -1, -1, -1, -1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, -1, -1, -1, -1, -1, -1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, 5, 5, 5, 5, 0, 2, 0, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, 2, 3, 4, 5, 0, 1, 0, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 6042
# evt.event: 297896
# crv.crvcoincs.time: [759, 779]
# crv.crvcoincs.timeStart: [774, 787]
# crv.crvcoincs.timeEnd: [862, 899]
# crv.crvcoincs.nHits: [16, 20]
# crv.crvcoincs.pos.fCoordinates.fZ: [-4.13e+03, -2.21e+03]
# dev.at_trk_front: [[False, False, False, False, True, ..., False, False, False, False], ...]
# dev.has_trk_front: [True, True, True, True]
# dev.at_trk_mid: [[False, False, False, True, False, ..., False, False, False, False], ...]
# dev.has_trk_mid: [True, True, True, True]
# dev.is_reco_electron: [True, False, False, False]
# dev.one_reco_electron: [True, True, True, True]
# dev.one_reco_electron_per_event: True
# dev.is_downstream: [True, False, True, False]
# dev.all_downstream: [False, False, False, False]
# dev.all_downstream_per_event: False
# dev.has_trk_parent_electron: [True, True, True, True]
# dev.good_trkqual: [True, False, True, False]
# dev.within_t0: [True, True, True, True]
# dev.within_t0err: [True, True, True, True]
# dev.has_hits: [True, True, True, True]
# dev.within_d0: [True, True, True, True]
# dev.pitch_angle: [[0.472, 0.473, 0.115, 0.74, 0.71, ..., -0.0494, -0.0515, 0.117, 0.115], ...]
# dev.within_pitch_angle_lo: [True, False, True, False]
# dev.within_pitch_angle_hi: [True, True, True, True]
# dev.within_lhr_max_lo: [True, True, True, True]
# dev.within_lhr_max_hi: [True, False, True, False]
# dev.veto_condition: [True, True]
# dev.vetoed: True
# dev.unvetoed: False
# dev.trk_times: [[786], [], [], []]
# dev.coinc_times: [759, 779]
# dev.dT_idx: [0, 1]
# dev.dT: [27.5, 7.87]
# dev.min_dT: [7.87]
# dev.min_dT_idx: [1]
# dev.cent_dT: [27.5]
# dev.cent_dT_idx: [0]
# dev.mom_mag: [[117, 117, 118, 117, 117, 116, 117, 118, 118, 118, 117], ..., [116, ..., 116]]
# dev.within_wide_win: [True, True, True, True]
# dev.within_ext_win: [False, False, False, False]
# dev.within_sig_win: [False, False, False, False]
# dev.preselect: [True, False, False, False]
# dev.select: [True, False, False, False]
# trk.trk.nactive: [63]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.917]
# trkfit.trksegs.mom.fCoordinates.fX: [[-105, 21.6, -88.6, -54.7, -95.4, -4, 100, -57.8, -94.4, -58.8, -94.3]]
# trkfit.trksegs.mom.fCoordinates.fY: [[-15.2, 104, 76.3, -76.3, 5.06, -91.1, -42.1, 102, 70, 101, 68.5]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[50, 50.2, 13.5, 69.4, 67.9, 72.2, 44.3, -5.81, -6.05, 13.7, 13.4]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-295, 42.9, -56.2, -514, -237, -578, -359, 2.43, -74.1, 2.94, -74.3]]
# trkfit.trksegs.pos.fCoordinates.fY: [[55.9, -297, -3.81, -81.1, 49.4, -252, -506, -75, 11.7, -74.9, 10.5]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-2.8e+03, -3.07e+03, -3.94e+03, 10.1, ..., -4.01e+03, -3.96e+03, -3.94e+03]]
# trkfit.trksegs.time: [[770, 768, 756, 786, 777, 795, 766, 750, 750, 756, 756]]
# trkfit.trksegs.dmom: [[-0.089, -0.0896, -0.334, 0, 0, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.0605, 0.0615, 0.0739, 0.0574, 0.0595, ..., nan, nan, 0.0739, 0.0615]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, ..., False, False, False, False, False]]
# trkfit.trksegs.sid: [[90, 90, 104, 1, 0, 2, 95, 103, 103, 103, 103]]
# trkfit.trksegs.sindex: [[0, 0, 34, 0, 0, 0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [