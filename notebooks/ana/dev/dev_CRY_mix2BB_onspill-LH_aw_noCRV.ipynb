# %% [markdown]
# # Analysis notebook: `dev_CRY_mix2BB_onspill-LH_aw_noCRV`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "dev_CRY_mix2BB_onspill-LH_aw_noCRV"

# %% [markdown]
# ## Preamble

# %%
import sys
sys.path.append("..")
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_noCRV
# Out:
# analysis.csv				 events.parquet
# cut_flow.csv				 hists.h5
# dev_CRY_mix2BB_onspill-LH_aw_noCRV.log	 info.txt
# dev_CRY_mix2BB_onspill-LH_aw_noCRV.yaml  results.pkl

# %%
loader = Load(
    in_path = f"../../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_noCRV

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_noCRV/results.pkl
# [Load] ✅ Loaded cut stats from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_noCRV/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_noCRV/hists.h5
# [Load] ✅ Loaded analysis info from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_noCRV/analysis.csv
# [Load] ✅ Successfully loaded ak.Array from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_noCRV/events.parquet
# [Load] ✅ Loaded info from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_noCRV/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                       Cut      Group  Events Passing  Absolute [%]  \
# 0                 No cuts        NaN         2160537           100
# 1           has_trk_front  Preselect         2126506        98.425
# 2             has_trk_mid  Preselect         2126502        98.425
# 3        is_reco_electron  Preselect         2054714        95.102
# 4       one_reco_electron  Preselect         1479491        68.478
# 5           is_downstream  Preselect          825750        38.220
# 6       is_truth_electron  Preselect          258259        11.953
# 7            good_trkqual    Tracker          182914         8.466
# 8               within_t0    Tracker          149420         6.916
# 9            within_t0err    Tracker          140902         6.522
# 10               has_hits    Tracker          139272         6.446
# 11              within_d0    Tracker           41050         1.900
# 12  within_pitch_angle_lo    Tracker           37137         1.719
# 13  within_pitch_angle_hi    Tracker           20557         0.951
# 14      within_lhr_max_hi    Tracker           16981         0.786
# 15        within_wide_win   Momentum           16450         0.761
# 16         within_ext_win   Momentum            2661         0.123
# 17         within_sig_win   Momentum             333         0.015
#
#     Relative [%]                                  Description
# 0            100                         No selection applied
# 1         98.425            Tracks intersect tracker entrance
# 2            100              Tracks intersect tracker middle
# 3         96.624                          Electron track fits
# 4         72.005                    One reco electron / event
# 5         55.813    Has downstream track (p_z > 0 in tracker)
# 6         31.276      Track parents are electrons (truth PID)
# 7         70.826                      Track fit quality > 0.2
# 8         81.689      t0 at tracker mid (640 < t_0 < 1650 ns)
# 9         94.299    Track fit t0 uncertainty (t0err < 0.9 ns)
# 10        98.843                      >20 active tracker hits
# 11        29.475  Distance of closest approach (d_0 < 100 mm)
# 12        90.468       Extrapolated pitch angle (pz/pt > 0.5)
# 13        55.354       Extrapolated pitch angle (pz/pt < 1.0)
# 14        82.604   Loop helix maximum radius (R_max < 680 mm)
# 15        96.873             Wide window (85 < p < 200 MeV/c)
# 16        16.176        Extended window (100 < p < 110 MeV/c)
# 17        12.514      Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Efficiency & rates

# %%
display(results["analysis"])
# Out:
# Window                                                 Inclusive  \
# Generated                                         41,100,000,000
# Selected                                                  16,981
# Unvetoed                                                       0
# Selection Eff [%]                                       4.13e-05
# Selection Eff Err$-$ [%]                               -3.16e-07
# Selection Eff Err$+$ [%]                                3.18e-07
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -0.006
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                         1.20e+04
# Selection Rate 1BB [$\text{day}^{-1}$]                     0.456
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.003
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.004
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.348
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.003
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.003
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            3.06e-05
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            2.34e-05
# Run-1 Livetimes                                          299.629
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                56.673
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -0.433
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0.436
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.004
#
# Window                                                      Wide  \
# Generated                                         41,100,000,000
# Selected                                                  16,450
# Unvetoed                                                       0
# Selection Eff [%]                                       4.00e-05
# Selection Eff Err$-$ [%]                               -3.11e-07
# Selection Eff Err$+$ [%]                                3.13e-07
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -0.006
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                         8.95e+03
# Selection Rate 1BB [$\text{day}^{-1}$]                     0.592
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.005
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.005
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.452
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.004
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.004
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            4.10e-05
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            3.13e-05
# Run-1 Livetimes                                          223.592
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                73.572
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -0.570
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0.575
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.005
#
# Window                                                  Extended  \
# Generated                                         41,100,000,000
# Selected                                                   2,661
# Unvetoed                                                       0
# Selection Eff [%]                                       6.47e-06
# Selection Eff Err$-$ [%]                               -1.24e-07
# Selection Eff Err$+$ [%]                                1.27e-07
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -0.038
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                          951.815
# Selection Rate 1BB [$\text{day}^{-1}$]                     0.900
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.017
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.018
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.688
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.013
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.014
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            3.85e-04
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            2.94e-04
# Run-1 Livetimes                                           23.768
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]               111.958
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -2.158
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          2.201
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.048
#
# Window                                                    Signal
# Generated                                         41,100,000,000
# Selected                                                     333
# Unvetoed                                                       0
# Selection Eff [%]                                       8.10e-07
# Selection Eff Err$-$ [%]                               -4.32e-08
# Selection Eff Err$+$ [%]                                4.56e-08
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -0.299
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                          123.611
# Selection Rate 1BB [$\text{day}^{-1}$]                     0.867
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.047
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.050
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.663
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.036
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.038
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]               0.003
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]               0.002
# Run-1 Livetimes                                            3.087
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]               107.882
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -5.877
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          6.208
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.369

# %% [markdown]
# ### Histograms

# %%
# Setup draw for this cutset
on_spill = "offspill" not in ana_label
draw = Draw(cutset_name=ana_label.split('_')[0], on_spill=on_spill)
# Define image directory
img_dir = f"../../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Load] ✅ Initialised with out_path=test_out
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_noCRV/h1o_1x3_mom_windows.png

# %%
draw.plot_summary(results["hists"], out_path=f"{img_dir}/h1o_3x3_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_noCRV/h1o_3x3_summary.png

# %%
draw.plot_mom_summary(results["hists"], out_path=f"{img_dir}/h1o_2x2_mom_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_noCRV/h1o_2x2_mom_summary.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_z.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_noCRV/h1o_crv_z.png

# %%
draw.draw_cosmic_parents_from_array(results["events"], out_path=f"{img_dir}/h1_cosmic_parents.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_noCRV/h1_cosmic_parents.png

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = len(results["events"]))
