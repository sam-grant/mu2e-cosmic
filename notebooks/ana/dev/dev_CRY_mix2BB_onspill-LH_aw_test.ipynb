# %% [markdown]
# # Analysis notebook: `dev_CRY_mix2BB_onspill-LH_aw_test`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "dev_CRY_mix2BB_onspill-LH_aw_test"

# %% [markdown]
# ## Preamble

# %%
import sys
sys.path.append("..")
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_test
# Out:
# analysis.csv  dev_CRY_mix2BB_onspill-LH_aw.log	 hists.h5
# cut_flow.csv  dev_CRY_mix2BB_onspill-LH_aw.yaml  results.pkl

# %%
loader = Load(
    in_path = f"../../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_test

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_test/results.pkl
# [Load] ✅ Loaded cut stats from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_test/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_test/hists.h5
# [Load] ✅ Loaded analysis info from ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_test/analysis.csv
# [Load] ⚠️ File not found: ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_test/events.parquet
# [Load] ⚠️ File not found: ../../../output/results/dev_CRY_mix2BB_onspill-LH_aw_test/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                       Cut      Group  Events Passing  Absolute [%]  \
# 0                 No cuts        NaN            2557           100
# 1           has_trk_front  Preselect            2513        98.279
# 2        is_reco_electron  Preselect            2433        95.151
# 3       one_reco_electron  Preselect            1730        67.657
# 4           is_downstream  Preselect             979        38.287
# 5       is_truth_electron  Preselect             284        11.107
# 6            good_trkqual    Tracker             200         7.822
# 7               within_t0    Tracker             168         6.570
# 8            within_t0err    Tracker             160         6.257
# 9                has_hits    Tracker             156         6.101
# 10              within_d0    Tracker              47         1.838
# 11  within_pitch_angle_lo    Tracker              43         1.682
# 12  within_pitch_angle_hi    Tracker              24         0.939
# 13      within_lhr_max_hi    Tracker              19         0.743
# 14               unvetoed        CRV               0             0
# 15        within_wide_win   Momentum               0             0
# 16         within_ext_win   Momentum               0             0
# 17         within_sig_win   Momentum               0             0
#
#     Relative [%]                                      Description
# 0            100                             No selection applied
# 1         98.279                Tracks intersect tracker entrance
# 2         96.817                              Electron track fits
# 3         71.106                        One reco electron / event
# 4         56.590  Downstream tracks (p_z > 0 at tracker entrance)
# 5         29.009          Track parents are electrons (truth PID)
# 6         70.423                          Track fit quality > 0.2
# 7             84     t0 at tracker entrance (640 < t_0 < 1650 ns)
# 8         95.238        Track fit t0 uncertainty (t0err < 0.9 ns)
# 9         97.500                          >20 active tracker hits
# 10        30.128      Distance of closest approach (d_0 < 100 mm)
# 11        91.489           Extrapolated pitch angle (pz/pt > 0.5)
# 12        55.814           Extrapolated pitch angle (pz/pt < 1.0)
# 13        79.167       Loop helix maximum radius (R_max < 680 mm)
# 14             0                   No veto: -25.0 < dT < 150.0 ns
# 15             0                 Wide window (85 < p < 200 MeV/c)
# 16             0            Extended window (100 < p < 110 MeV/c)
# 17             0          Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Efficiency & rates

# %%
display(results["analysis"])
# Out:
# Window                                                 Inclusive  \
# Generated                                         41,100,000,000
# Selected                                                      19
# Unvetoed                                                       0
# Selection Eff [%]                                       4.62e-08
# Selection Eff Err$-$ [%]                               -9.46e-09
# Selection Eff Err$+$ [%]                                1.19e-08
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -5.000
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                         9.52e+03
# Selection Rate 1BB [$\text{day}^{-1}$]                  6.42e-04
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]          -1.45e-04
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]           1.83e-04
# Selection Rate 2BB [$\text{day}^{-1}$]                  4.91e-04
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]          -1.11e-04
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]           1.40e-04
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            3.85e-05
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            2.94e-05
# Run-1 Livetimes                                          237.797
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                 0.080
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -0.018
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0.023
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.005
#
# Window                                                      Wide  \
# Generated                                         41,100,000,000
# Selected                                                      19
# Unvetoed                                                       0
# Selection Eff [%]                                       4.62e-08
# Selection Eff Err$-$ [%]                               -9.46e-09
# Selection Eff Err$+$ [%]                                1.19e-08
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                       -5.000
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                         7.16e+03
# Selection Rate 1BB [$\text{day}^{-1}$]                  8.54e-04
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]          -1.93e-04
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]           2.43e-04
# Selection Rate 2BB [$\text{day}^{-1}$]                  6.52e-04
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]          -1.48e-04
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]           1.86e-04
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            5.12e-05
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            3.91e-05
# Run-1 Livetimes                                          178.908
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                 0.106
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -0.024
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0.030
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.006
#
# Window                                                  Extended  \
# Generated                                         41,100,000,000
# Selected                                                       3
# Unvetoed                                                       0
# Selection Eff [%]                                       7.30e-09
# Selection Eff Err$-$ [%]                               -3.17e-09
# Selection Eff Err$+$ [%]                                5.60e-09
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                          -25
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                          790.142
# Selection Rate 1BB [$\text{day}^{-1}$]                     0.001
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]          -6.63e-04
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.001
# Selection Rate 2BB [$\text{day}^{-1}$]                  9.34e-04
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]          -5.07e-04
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]           9.04e-04
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]            4.64e-04
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]            3.55e-04
# Run-1 Livetimes                                           19.731
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                 0.152
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -0.082
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0.147
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.058
#
# Window                                                    Signal
# Generated                                         41,100,000,000
# Selected                                                       1
# Unvetoed                                                       0
# Selection Eff [%]                                       2.43e-09
# Selection Eff Err$-$ [%]                               -1.50e-09
# Selection Eff Err$+$ [%]                                3.94e-09
# Veto Eff [%]                                                 100
# Veto Eff Err$-$ [%]                                          -50
# Veto Eff Err$+$ [%]                                            0
# Livetime [days]                                          123.611
# Selection Rate 1BB [$\text{day}^{-1}$]                     0.003
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             -0.002
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0.006
# Selection Rate 2BB [$\text{day}^{-1}$]                     0.002
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             -0.002
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0.005
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]               0.003
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                          0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]                   0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]               0.002
# Run-1 Livetimes                                            3.087
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                 0.324
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         -0.267
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0.741
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                      0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]               0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0.369

# %% [markdown]
# ### Histograms

# %%
# Setup draw for this cutset
on_spill = "offspill" not in ana_label
draw = Draw(cutset_name=ana_label.split('_')[0], on_spill=on_spill)
# Define image directory
img_dir = f"../../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Load] ✅ Initialised with out_path=test_out
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_test/h1o_1x3_mom_windows.png

# %%
draw.plot_summary(results["hists"], out_path=f"{img_dir}/h1o_3x3_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_test/h1o_3x3_summary.png

# %%
draw.plot_mom_summary(results["hists"], out_path=f"{img_dir}/h1o_2x2_mom_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_test/h1o_2x2_mom_summary.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_z.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_CRY_mix2BB_onspill-LH_aw_test/h1o_crv_z.png

# %%
# draw.plot_cosmic_parents(results["hists"], out_path=f"{img_dir}/h1_cosmic_parents.png") 
draw.draw_cosmic_parents_from_array(results["events"], out_path=f"{img_dir}/h1_cosmic_parents.png")
# Out:
# [Plot] ❌ Error extracting cosmic parents: list indices must be integers or slices, not str

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = len(results["events"]))
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [pyprint] ⭐️ Printing 0 event(s)...
