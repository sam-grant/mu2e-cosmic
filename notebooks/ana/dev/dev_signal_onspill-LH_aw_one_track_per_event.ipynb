# %% [markdown]
# # Analysis notebook: `dev_signal_onspill-LH_aw_one_track_per_event`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "dev_signal_onspill-LH_aw_one_track_per_event"

# %% [markdown]
# ## Preamble

# %%
import sys
sys.path.append("..")
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../../output/results/dev_signal_onspill-LH_aw_one_track_per_event
# Out:
# analysis.csv  dev_signal_onspill-LH_aw.log   events.parquet  results.pkl
# cut_flow.csv  dev_signal_onspill-LH_aw.yaml  hists.h5

# %%
loader = Load(
    in_path = f"../../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../../output/results/dev_signal_onspill-LH_aw_one_track_per_event

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../../output/results/dev_signal_onspill-LH_aw_one_track_per_event/results.pkl
# [Load] ✅ Loaded cut stats from ../../../output/results/dev_signal_onspill-LH_aw_one_track_per_event/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../../output/results/dev_signal_onspill-LH_aw_one_track_per_event/hists.h5
# [Load] ✅ Loaded analysis info from ../../../output/results/dev_signal_onspill-LH_aw_one_track_per_event/analysis.csv
# [Load] ✅ Successfully loaded ak.Array from ../../../output/results/dev_signal_onspill-LH_aw_one_track_per_event/events.parquet
# [Load] ⚠️ File not found: ../../../output/results/dev_signal_onspill-LH_aw_one_track_per_event/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                         Cut      Group  Events Passing  Absolute [%]  \
# 0                   No cuts        NaN         1493499           100
# 1             has_trk_front  Preselect         1493210        99.981
# 2               has_trk_mid  Preselect         1493210        99.981
# 3       one_track_per_event  Preselect         1436300        96.170
# 4          is_reco_electron  Preselect         1435155        96.093
# 5             is_downstream  Preselect         1435151        96.093
# 6         is_truth_electron  Preselect         1435150        96.093
# 7              good_trkqual    Tracker         1307340        87.535
# 8                 within_t0    Tracker          947813        63.463
# 9              within_t0err    Tracker          912336        61.087
# 10                 has_hits    Tracker          884235        59.206
# 11                within_d0    Tracker          878867        58.846
# 12    within_pitch_angle_lo    Tracker          878760        58.839
# 13    within_pitch_angle_hi    Tracker          813593        54.476
# 14        within_lhr_max_hi    Tracker          813575        54.474
# 15  within_coinc_start_time        CRV          813575        54.474
# 16    within_coinc_end_time        CRV          813575        54.474
# 17                 unvetoed       Veto          813574        54.474
# 18          within_wide_win   Momentum          811821        54.357
# 19           within_ext_win   Momentum          768647        51.466
# 20           within_sig_win   Momentum          567957        38.029
#
#     Relative [%]                                  Description
# 0            100                         No selection applied
# 1         99.981            Tracks intersect tracker entrance
# 2            100              Tracks intersect tracker middle
# 3         96.189                            One track / event
# 4         99.920                          Electron track fits
# 5            100  Downstream tracks (p_z > 0 through tracker)
# 6            100      Track parents are electrons (truth PID)
# 7         91.094                          Track quality > 0.2
# 8         72.499      t0 at tracker mid (640 < t_0 < 1650 ns)
# 9         96.257    Track fit t0 uncertainty (t0err < 0.9 ns)
# 10        96.920                      >20 active tracker hits
# 11        99.393  Distance of closest approach (d_0 < 100 mm)
# 12        99.988       Extrapolated pitch angle (pz/pt > 0.5)
# 13        92.584       Extrapolated pitch angle (pz/pt < 1.0)
# 14        99.998   Loop helix maximum radius (R_max < 680 mm)
# 15           100  Coincidence start time (t_start > 420.0 ns)
# 16           100     Coincidence end time (t_end < 1700.0 ns)
# 17           100                  Veto: -25.0 < dT < 150.0 ns
# 18        99.785             Wide window (85 < p < 200 MeV/c)
# 19        94.682        Extended window (100 < p < 110 MeV/c)
# 20        73.890      Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Efficiency & rates

# %%
display(results["analysis"])
# Out:
# Window                                             Inclusive      Wide  \
# Generated                                          4,000,000 4,000,000
# Selected                                             813,575   811,822
# Unvetoed                                             813,574   811,821
# Selection Eff [%]                                     20.339    20.296
# Selection Eff Err$-$ [%]                              -0.020    -0.020
# Selection Eff Err$+$ [%]                               0.020     0.020
# Veto Eff [%]                                        1.23e-04  1.23e-04
# Veto Eff Err$-$ [%]                                -7.60e-05 -7.61e-05
# Veto Eff Err$+$ [%]                                 1.99e-04  1.99e-04
# Livetime [days]                                            0         0
# Selection Rate 1BB [$\text{day}^{-1}$]                     0         0
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]              0         0
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]              0         0
# Selection Rate 2BB [$\text{day}^{-1}$]                     0         0
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]              0         0
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]              0         0
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                      0         0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]               0         0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]               0         0
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                      0         0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]               0         0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]               0         0
# Run-1 Livetimes                                            0         0
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                 0         0
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]          0         0
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0         0
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                  0         0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]           0         0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]           0         0
#
# Window                                             Extended    Signal
# Generated                                         4,000,000 4,000,000
# Selected                                            768,648   567,958
# Unvetoed                                            768,647   567,957
# Selection Eff [%]                                    19.216    14.199
# Selection Eff Err$-$ [%]                             -0.020    -0.017
# Selection Eff Err$+$ [%]                              0.020     0.017
# Veto Eff [%]                                       1.30e-04  1.76e-04
# Veto Eff Err$-$ [%]                               -8.04e-05 -1.09e-04
# Veto Eff Err$+$ [%]                                2.11e-04  2.85e-04
# Livetime [days]                                           0         0
# Selection Rate 1BB [$\text{day}^{-1}$]                    0         0
# Selection Rate 1BB Err$-$ [$\text{day}^{-1}$]             0         0
# Selection Rate 1BB Err$+$ [$\text{day}^{-1}$]             0         0
# Selection Rate 2BB [$\text{day}^{-1}$]                    0         0
# Selection Rate 2BB Err$-$ [$\text{day}^{-1}$]             0         0
# Selection Rate 2BB Err$+$ [$\text{day}^{-1}$]             0         0
# Unvetoed Rate 1BB [$\text{day}^{-1}$]                     0         0
# Unvetoed Rate 1BB Err$-$ [$\text{day}^{-1}$]              0         0
# Unvetoed Rate 1BB Err$+$ [$\text{day}^{-1}$]              0         0
# Unvetoed Rate 2BB [$\text{day}^{-1}$]                     0         0
# Unvetoed Rate 2BB Err$-$ [$\text{day}^{-1}$]              0         0
# Unvetoed Rate 2BB Err$+$ [$\text{day}^{-1}$]              0         0
# Run-1 Livetimes                                           0         0
# Selection Rate Run-1 [$\text{Run-1}^{-1}$]                0         0
# Selection Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]         0         0
# Selection Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]         0         0
# Unvetoed Rate Run-1 [$\text{Run-1}^{-1}$]                 0         0
# Unvetoed Rate Run-1 Err$-$ [$\text{Run-1}^{-1}$]          0         0
# Unvetoed Rate Run-1 Err$+$ [$\text{Run-1}^{-1}$]          0         0

# %% [markdown]
# ### Histograms

# %%
# Setup draw for this cutset
on_spill = "offspill" not in ana_label
draw = Draw(cutset_name=ana_label.split('_')[0], on_spill=on_spill)
# Define image directory
img_dir = f"../../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Load] ✅ Initialised with out_path=test_out
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw_one_track_per_event/h1o_1x3_mom_windows.png

# %%
draw.plot_summary(results["hists"], out_path=f"{img_dir}/h1o_3x3_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw_one_track_per_event/h1o_3x3_summary.png

# %%
draw.plot_mom_summary(results["hists"], out_path=f"{img_dir}/h1o_2x2_mom_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw_one_track_per_event/h1o_2x2_mom_summary.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_z.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw_one_track_per_event/h1o_crv_z.png

# %%
draw.draw_cosmic_parents_from_array(results["events"], out_path=f"{img_dir}/h1_cosmic_parents.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/dev_signal_onspill-LH_aw_one_track_per_event/h1_cosmic_parents.png

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
# if results["events"] is not None:
#     from pyutils.pyprint import Print
#     printer = Print()
#     printer.print_n_events(results["events"], n_events = len(results["events"]))
