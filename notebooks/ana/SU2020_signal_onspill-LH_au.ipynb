# %% [markdown]
# # Analysis notebook: `SU2020_signal_onspill-LH_au`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "SU2020_signal_onspill-LH_au"

# %% [markdown]
# ## Preamble

# %%
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../output/results/SU2020_signal_onspill-LH_au
# Out:
# cut_flow.csv	hists.h5     SU2020_signal_onspill-LH_au.log
# efficiency.csv	results.pkl  SU2020_signal_onspill-LH_au.yaml

# %%
loader = Load(
    in_path = f"../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../output/results/SU2020_signal_onspill-LH_au

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../output/results/SU2020_signal_onspill-LH_au/results.pkl
# [Load] ✅ Loaded cut stats from ../../output/results/SU2020_signal_onspill-LH_au/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../output/results/SU2020_signal_onspill-LH_au/hists.h5
# [Load] ✅ Loaded efficiency info from ../../output/results/SU2020_signal_onspill-LH_au/efficiency.csv
# [Load] ⚠️ File not found: ../../output/results/SU2020_signal_onspill-LH_au/events.parquet
# [Load] ⚠️ File not found: ../../output/results/SU2020_signal_onspill-LH_au/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                    Cut  Events Passing  Absolute [%]  Relative [%]  \
# 0              No cuts         1454548    100.000000    100.000000
# 1     is_reco_electron         1453474     99.926163     99.926163
# 2        has_trk_front         1428881     98.235397     98.307985
# 3         good_trkqual          792122     54.458292     55.436527
# 4            within_t0          572713     39.373950     72.301110
# 5        is_downstream          572704     39.373331     99.998429
# 6             has_hits          568928     39.113732     99.340672
# 7         within_t0err          324724     22.324736     57.076467
# 8            within_d0          321304     22.089611     98.946798
# 9   within_pitch_angle          289710     19.917528     90.166945
# 10   within_lhr_max_hi          289644     19.912990     99.977219
# 11   is_truth_electron          289644     19.912990    100.000000
# 12   one_reco_electron          289344     19.892365     99.896425
# 13      within_ext_win          277063     19.048048     95.755571
# 14      within_sig_win          215096     14.787824     77.634329
#
#                                           Description
# 0                                No selection applied
# 1                                 Electron track fits
# 2                   Tracks intersect tracker entrance
# 3                             Track fit quality > 0.8
# 4        t0 at tracker entrance (640 < t_0 < 1650 ns)
# 5     Downstream tracks (p_z > 0 at tracker entrance)
# 6                             >20 active tracker hits
# 7           Track fit t0 uncertainty (t0err < 0.9 ns)
# 8         Distance of closest approach (d_0 < 100 mm)
# 9   Extrapolated pitch angle (0.5 < tan(theta_Dip)...
# 10         Loop helix maximum radius (R_max < 680 mm)
# 11            Track parents are electrons (truth PID)
# 12                          One reco electron / event
# 13              Extended window (100 < p < 110 MeV/c)
# 14            Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Histograms

# %%
draw = Draw()

# Define image directory
img_dir = f"../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/SU2020_signal_onspill-LH_au/h1o_1x3_mom_windows.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_zwindows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/SU2020_signal_onspill-LH_au/h1o_crv_zwindows.png

# %%
draw.plot_trk_params(results["hists"])

# %%
# draw.plot_trkfit_params(results["hists"])
draw.plot_trkfit_params_SU2020(results["hists"])

# %% [markdown]
# ### Efficiency

# %%
display(results["efficiency"])
# Out:
#             Type  Events Passing (k)  Total Events (N)  Efficiency [%]  \
# 0  Signal (wide)              289344           4000000            7.23
# 1   Signal (ext)              277063           4000000            6.93
# 2   Signal (sig)              215096           4000000            5.38
# 3    Veto (wide)                   0            289344          100.00
# 4     Veto (ext)                   0            277063          100.00
# 5     Veto (sig)                   0            215096          100.00
#
#    Efficiency Error [%]
# 0                  0.01
# 1                  0.01
# 2                  0.01
# 3                  0.00
# 4                  0.00
# 5                  0.00

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = len(results["events"]))
