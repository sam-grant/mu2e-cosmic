# %% [markdown]
# # Analysis notebook: `SU2020_CRY_onspill-LH_aq`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "SU2020_CRY_onspill-LH_aq"

# %% [markdown]
# ## Preamble

# %%
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../output/results/SU2020_CRY_onspill-LH_aq
# Out:
# cut_flow.csv	events.parquet	info.txt     SU2020_CRY_onspill-LH_aq.log
# efficiency.csv	hists.h5	results.pkl  SU2020_CRY_onspill-LH_aq.yaml

# %%
loader = Load(
    in_path = f"../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../output/results/SU2020_CRY_onspill-LH_aq

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../output/results/SU2020_CRY_onspill-LH_aq/results.pkl
# [Load] ✅ Loaded cut stats from ../../output/results/SU2020_CRY_onspill-LH_aq/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../output/results/SU2020_CRY_onspill-LH_aq/hists.h5
# [Load] ✅ Loaded efficiency info from ../../output/results/SU2020_CRY_onspill-LH_aq/efficiency.csv
# [Load] ✅ Successfully loaded ak.Array from ../../output/results/SU2020_CRY_onspill-LH_aq/events.parquet
# [Load] ✅ Loaded info from ../../output/results/SU2020_CRY_onspill-LH_aq/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                    Cut  Events Passing  Absolute [%]  Relative [%]  \
# 0              No cuts         2530885    100.000000    100.000000
# 1     is_reco_electron         2439133     96.374707     96.374707
# 2        has_trk_front         2410132     95.228823     98.811012
# 3         good_trkqual          372972     14.736821     15.475169
# 4            within_t0          303102     11.976127     81.266690
# 5        is_downstream          217249      8.583914     71.675212
# 6             has_hits          216495      8.554122     99.652933
# 7         within_t0err          201777      7.972587     93.201691
# 8            within_d0           66375      2.622600     32.895226
# 9   within_pitch_angle           37024      1.462887     55.780038
# 10   within_lhr_max_hi           30573      1.207996     82.576167
# 11   is_truth_electron           19760      0.780755     64.632192
# 12   one_reco_electron           10865      0.429296     54.984818
# 13            unvetoed               3      0.000119      0.027612
# 14      within_ext_win               1      0.000040     33.333333
# 15      within_sig_win               0      0.000000      0.000000
#
#                                           Description
# 0                                No selection applied
# 1                                 Electron track fits
# 2                   Tracks intersect tracker entrance
# 3                             Track fit quality > 0.8
# 4        t0 at tracker entrance (640 < t_0 < 1650 ns)
# 5     Downstream tracks (p_z > 0 at tracker entrance)
# 6                             >20 active tracker hits
# 7           Track fit t0 uncertainty (t0err < 0.9 ns)
# 8         Distance of closest approach (d_0 < 100 mm)
# 9   Extrapolated pitch angle (0.5 < tan(theta_Dip)...
# 10         Loop helix maximum radius (R_max < 680 mm)
# 11            Track parents are electrons (truth PID)
# 12                          One reco electron / event
# 13                            No veto: |dt| >= 150 ns
# 14              Extended window (100 < p < 110 MeV/c)
# 15            Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Histograms

# %%
draw = Draw()

# Define image directory
img_dir = f"../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/SU2020_CRY_onspill-LH_aq/h1o_1x3_mom_windows.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_zwindows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/SU2020_CRY_onspill-LH_aq/h1o_crv_zwindows.png

# %%
draw.plot_trk_params(results["hists"])

# %%
# draw.plot_trkfit_params(results["hists"])
draw.plot_trkfit_params_SU2020(results["hists"])

# %% [markdown]
# ### Efficiency

# %%
display(results["efficiency"])
# Out:
#             Type  Events Passing (k)  Total Events (N)  Efficiency [%]  \
# 0  Signal (wide)               10865           4000000            0.27
# 1   Signal (ext)                1707           4000000            0.04
# 2   Signal (sig)                 198           4000000            0.00
# 3    Veto (wide)                   3             10865           99.97
# 4     Veto (ext)                   1              1707           99.94
# 5     Veto (sig)                   0               198          100.00
#
#    Efficiency Error [%]
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.02
# 4                  0.07
# 5                  0.25

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
#   Index:            14
#   Subrun:           [4846]
#   Event:            [283585]
#   File:             nts.mu2e.CosmicCRYSignalAllOnSpillTriggered.MDC2020aq_best_v1_3_v06_03_00.001202_00000075.root
#   Track time [ns]:  1446.661210
#   Coinc time [ns]:  None
#   dt [ns]:          N/A
# ----------------------------------------
#   Index:            217
#   Subrun:           [19742]
#   Event:            [359830]
#   File:             nts.mu2e.CosmicCRYSignalAllOnSpillTriggered.MDC2020aq_best_v1_3_v06_03_00.001202_00015581.root
#   Track time [ns]:  822.497897
#   Coinc time [ns]:  None
#   dt [ns]:          N/A
# ----------------------------------------
#   Index:            755
#   Subrun:           [78889]
#   Event:            [161916]
#   File:             nts.mu2e.CosmicCRYSignalAllOnSpillTriggered.MDC2020aq_best_v1_3_v06_03_00.001202_00070146.root
#   Track time [ns]:  1628.524816
#   Coinc time [ns]:  None
#   dt [ns]:          N/A
# ----------------------------------------

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = len(results["events"]))
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [pyprint] ⭐️ Printing 3 event(s)...
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 4846
# evt.event: 283585
# crv.crvcoincs.time: []
# crv.crvcoincs.nHits: []
# crv.crvcoincs.pos.fCoordinates.fZ: []
# is_reco_electron: [True, False, False, False]
# at_trk_front: [[False, False, False, False, False, True, False, False], ..., [False, ...]]
# has_trk_front: [True, True, True, True]
# good_trkqual: [True, False, False, False]
# within_t0: [True, True, True, True]
# is_downstream: [True, False, True, False]
# has_hits: [True, True, True, True]
# within_t0err: [True, False, True, False]
# within_d0: [True, True, True, True]
# within_pitch_angle: [True, False, True, False]
# within_lhr_max: [True, False, True, False]
# within_lhr_max_hi: [True, True, True, True]
# is_truth_electron: [True, True, True, True]
# one_reco_electron: [True, True, True, True]
# one_reco_electron_per_event: True
# unvetoed: [True, True, True, True]
# within_ext_win: [False, False, False, False]
# within_sig_win: [False, False, False, False]
# CE_like: [True, False, False, False]
# unvetoed_CE_like: [True, False, False, False]
# trk.trk.nactive: [26]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.986]
# trkfit.trksegs.mom.fCoordinates.fX: [[-13.2, 9.77, 28, -86.1, -83.8, 68.9, 74.8, 83.7]]
# trkfit.trksegs.mom.fCoordinates.fY: [[-115, -104, -101, 47.5, -29.6, 53, 41.5, 12.5]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[27.5, 57.4, 57.5, 67.3, 79.4, 81.3, 82.4, 83.1]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-56.6, -63.8, -56.5, 281, 99.7, 372, 339, 244]]
# trkfit.trksegs.pos.fCoordinates.fY: [[51.3, 6.04, -33.7, 241, 283, -189, -213, -250]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-5.97e+03, -4.48e+03, -4.46e+03, -3.9e+03, ..., -1.63e+03, 10.1, 1.64e+03]]
# trkfit.trksegs.time: [[1.42e+03, 1.43e+03, 1.43e+03, 1.43e+03, ..., 1.45e+03, 1.45e+03, 1.46e+03]]
# trkfit.trksegs.dmom: [[0, -0.0733, -0.0731, 0, -0.168, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.0842, 0.0842, 0.0837, 0.0831, 0.0831, 0.0806, 0.0775, 0.0761]]
# trkfit.trksegs.inbounds: [[False, True, True, False, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, False, False, False]]
# trkfit.trksegs.early: [[True, False, False, False, False, False, False, False]]
# trkfit.trksegs.late: [[False, False, False, False, False, False, False, True]]
# trkfit.trksegs.sid: [[96, 104, 104, 101, 90, 0, 1, 2]]
# trkfit.trksegs.sindex: [[0, 10, 11, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[503, 368, 366, 487, 486, 489, 331, 525]]
# trkfit.trksegpars_lh.d0: [[35.9, 88.1, 88.8, 72.8, 78.1, 79.6, 78, 46.6]]
# trkfit.trksegpars_lh.tanDip: [[0.826, 0.549, 0.541, 0.934, 0.963, 0.983, 0.23, 0.649]]
# trkfit.trksegpars_lh.rad: [[269, 228, 228, 280, 282, 285, 204, 239]]
# trkfit.trksegpars_lh.lam: [[233, 126, 125, 262, 272, 279, 48, 160]]
# trkfit.trksegpars_lh.cx: [[216, 139, 136, 205, 201, 202, 119, 264]]
# trkfit.trksegpars_lh.cy: [[89, 11.8, 27, 28.6, 33.6, 34.3, 42.2, 109]]
# trkfit.trksegpars_lh.phi0: [[1.64, 2.65, 2.99, 0.594, 0.47, 0.558, -3.04, 1.86]]
# trkfit.trksegpars_lh.t0: [[1.46e+03, 1.46e+03, 1.46e+03, 1.45e+03, ..., 1.45e+03, 1.5e+03, 1.46e+03]]
# trkfit.trksegpars_lh.raderr: [[1.37, 0.862, 1.03, 0.765, 0.494, 0.881, 0.411, 0.789]]
# trkfit.trksegpars_lh.lamerr: [[1.57, 1.53, 1.87, 0.818, 0.216, 0.892, 1.66, 1.16]]
# trkfit.trksegpars_lh.cxerr: [[1.64, 1.61, 1.72, 0.823, 0.702, 1.04, 2.77, 4.83]]
# trkfit.trksegpars_lh.cyerr: [[7.16, 3.78, 4.42, 1.04, 0.188, 0.824, 5.1, 8.16]]
# trkfit.trksegpars_lh.phi0err: [[0.0499, 0.419, 0.526, 0.0178, 0.00175, 0.00713, 3.77, 0.184]]
# trkfit.trksegpars_lh.t0err: [[0.42, 0.551, 0.615, 0.458, 0.459, 0.459, 2.72, 0.457]]
# trkmc.trkmcsim.valid: [[True, True, True]]
# trkmc.trkmcsim.id: [[2, 0, 0]]
# trkmc.trkmcsim.nhits: [[26, -1, -1]]
# trkmc.trkmcsim.nactive: [[26, -1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, -1]]
# trkmc.trkmcsim.pdg: [[11, 13, 13]]
# trkmc.trkmcsim.startCode: [[14, 56, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, 38]]
# trkmc.trkmcsim.time: [[5.91e+04, 5.88e+04, 5.88e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[-75.4, -7.78e+03, -7.78e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[75, -2.45e+03, -2.45e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[55.2, 6.87e+03, 6.87e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[317, 5.11e+04, 5.11e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[180, 1.54e+04, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-4.81e+03, -5.37e+04, -5.37e+04]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[-0, -320, -320]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[-0, 41.7, 41.7]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, 227, 227]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[336, 581, 581]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[-221, 550, 550]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.72e+03, -7.13e+03, -7.13e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 19742
# evt.event: 359830
# crv.crvcoincs.time: []
# crv.crvcoincs.nHits: []
# crv.crvcoincs.pos.fCoordinates.fZ: []
# is_reco_electron: [True, False, False, False]
# at_trk_front: [[False, False, False, True, False, False], ..., [False, True, ..., True]]
# has_trk_front: [True, True, True, True]
# good_trkqual: [True, False, False, False]
# within_t0: [True, True, True, True]
# is_downstream: [True, False, True, False]
# has_hits: [True, True, True, True]
# within_t0err: [True, False, True, False]
# within_d0: [True, False, True, True]
# within_pitch_angle: [True, False, True, False]
# within_lhr_max: [True, False, True, True]
# within_lhr_max_hi: [True, False, True, True]
# is_truth_electron: [True, True, True, True]
# one_reco_electron: [True, True, True, True]
# one_reco_electron_per_event: True
# unvetoed: [True, True, True, True]
# within_ext_win: [False, False, False, False]
# within_sig_win: [False, False, False, False]
# CE_like: [True, False, False, False]
# unvetoed_CE_like: [True, False, False, False]
# trk.trk.nactive: [55]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.968]
# trkfit.trksegs.mom.fCoordinates.fX: [[135, 77.6, -121, -113, -105, -101]]
# trkfit.trksegs.mom.fCoordinates.fY: [[9.14, 98.7, 30.5, 9.58, -36.5, -41.2]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[-2.24, 50.6, 52.4, 73.5, 76, 77.7]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-215, 23.5, -168, -231, -388, -415]]
# trkfit.trksegs.pos.fCoordinates.fY: [[-409, -299, 249, 275, 254, 250]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-3.9e+03, -3.21e+03, -2.93e+03, -1.63e+03, 10.1, 1.64e+03]]
# trkfit.trksegs.time: [[796, 811, 814, 822, 832, 842]]
# trkfit.trksegs.dmom: [[0, -0.113, -0.112, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.0952, 0.0953, 0.0943, 0.0933, 0.0904, 0.0888]]
# trkfit.trksegs.inbounds: [[False, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, False]]
# trkfit.trksegs.early: [[True, False, False, False, False, False]]
# trkfit.trksegs.late: [[False, False, False, False, False, True]]
# trkfit.trksegs.sid: [[101, 90, 90, 0, 1, 2]]
# trkfit.trksegs.sindex: [[0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[630, 639, 644, 648, 654, 700]]
# trkfit.trksegpars_lh.d0: [[67.9, 50.2, 84, 82.5, 79.2, 46.4]]
# trkfit.trksegpars_lh.tanDip: [[0.427, 0.384, 0.651, 0.685, 0.712, -0.0731]]
# trkfit.trksegpars_lh.rad: [[349, 344, 364, 365, 366, 327]]
# trkfit.trksegpars_lh.lam: [[151, 132, 238, 252, 262, -11.8]]
# trkfit.trksegpars_lh.cx: [[-276, -246, -267, -268, -273, -304]]
# trkfit.trksegpars_lh.cy: [[-51.7, -162, -84.7, -91.4, -88.6, -218]]
# trkfit.trksegpars_lh.phi0: [[-2.92, 0.0978, -2.66, -2.85, -2.73, -2.34]]
# trkfit.trksegpars_lh.t0: [[838, 841, 832, 832, 832, 437]]
# trkfit.trksegpars_lh.raderr: [[0.668, 0.683, 0.813, 0.463, 0.555, 0.237]]
# trkfit.trksegpars_lh.lamerr: [[1.43, 1.67, 1.18, 0.482, 0.722, 1.58]]
# trkfit.trksegpars_lh.cxerr: [[5.42, 4.13, 1.27, 0.832, 1.14, 7]]
# trkfit.trksegpars_lh.cyerr: [[5.57, 1.75, 1.06, 0.31, 0.62, 3.91]]
# trkfit.trksegpars_lh.phi0err: [[0.197, 0.29, 0.0305, 0.00168, 0.00959, 46.9]]
# trkfit.trksegpars_lh.t0err: [[0.533, 0.58, 0.417, 0.416, 0.417, 51.2]]
# trkmc.trkmcsim.valid: [[True, True, True, True, True, True]]
# trkmc.trkmcsim.id: [[4, 3, 2, 0, 6, 0]]
# trkmc.trkmcsim.nhits: [[54, -1, -1, -1, 1, -1]]
# trkmc.trkmcsim.nactive: [[54, -1, -1, -1, 1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, -1, -1, 1, -1]]
# trkmc.trkmcsim.pdg: [[11, 22, 111, 2112, 11, 2112]]
# trkmc.trkmcsim.startCode: [[13, 14, 97, 56, 17, 56]]
# trkmc.trkmcsim.stopCode: [[17, 13, 14, 54, 17, 54]]
# trkmc.trkmcsim.gen: [[-1, -1, -1, 38, -1, 38]]
# trkmc.trkmcsim.time: [[3.13e+04, 3.13e+04, 3.13e+04, 3.13e+04, 3.13e+04, 3.13e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2, 3, 4, 5]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[50.6, 51.9, -17.6, 207, 0.108, 207]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-948, -963, -2.3e+03, -4.92e+03, 0.136, -4.92e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[-27.4, -28.6, 4.27, -711, -0.0525, -711]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[-746, -771, -771, -1.42e+03, -350, -1.42e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[608, 1.06e+03, 1.06e+03, 1.54e+04, -445, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-3.9e+03, -3.89e+03, -3.89e+03, -1.9e+03, -916, -1.9e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[0, 51.9, -17.6, 285, -0, 285]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[0, -963, -2.3e+03, -4.94e+03, 0, -4.94e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, -28.6, 4.27, -579, -0, -579]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-521, -746, -771, -770, -351, -770]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[171, 608, 1.06e+03, 1.05e+03, -445, 1.05e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.73e+03, -3.9e+03, -3.89e+03, -3.89e+03, -917, -3.89e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, -1, -1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, -1, -1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, 5, 5, 0, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, 2, 3, 0, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 78889
# evt.event: 161916
# crv.crvcoincs.time: []
# crv.crvcoincs.nHits: []
# crv.crvcoincs.pos.fCoordinates.fZ: []
# is_reco_electron: [True, False, False, False]
# at_trk_front: [[False, False, False, False, False, False, True, False, False], ..., [...]]
# has_trk_front: [True, True, True, True]
# good_trkqual: [True, False, False, False]
# within_t0: [True, False, True, False]
# is_downstream: [True, False, True, False]
# has_hits: [True, True, True, True]
# within_t0err: [True, False, True, False]
# within_d0: [True, False, True, True]
# within_pitch_angle: [True, False, True, False]
# within_lhr_max: [True, True, True, True]
# within_lhr_max_hi: [True, True, True, True]
# is_truth_electron: [True, True, True, True]
# one_reco_electron: [True, True, True, True]
# one_reco_electron_per_event: True
# unvetoed: [True, True, True, True]
# within_ext_win: [True, True, True, True]
# within_sig_win: [False, True, False, False]
# CE_like: [True, False, False, False]
# unvetoed_CE_like: [True, False, False, False]
# trk.trk.nactive: [34]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.977]
# trkfit.trksegs.mom.fCoordinates.fX: [[94.9, 96.4, 95.1, 97.9, 93.1, 42.8, 11, -43.2, -69.4]]
# trkfit.trksegs.mom.fCoordinates.fY: [[-17.3, -1.38, 15.3, -8.87, -2.53, 74.9, 77.3, 63.7, 32.1]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[-43.6, -43.7, -43.7, 38.9, 49.8, 60.9, 70.9, 72, 71.8]]
# trkfit.trksegs.pos.fCoordinates.fX: [[