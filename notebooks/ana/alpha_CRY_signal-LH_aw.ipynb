# %% [markdown]
# # Analysis notebook: `alpha_CRY_signal-LH_aw`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "alpha_CRY_signal-LH_aw"

# %% [markdown]
# ## Preamble

# %%
from preamble import *

# %% [markdown]
# # Load data

# %%
# !ls ../../output/results/alpha_CRY_signal-LH_aw
# Out:
# alpha_CRY_signal-LH_aw.log   cut_flow.csv    hists.h5
# alpha_CRY_signal-LH_aw.yaml  efficiency.csv  results.pkl

# %%
loader = Load(
    in_path = f"../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../output/results/alpha_CRY_signal-LH_aw

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../output/results/alpha_CRY_signal-LH_aw/results.pkl
# [Load] ✅ Loaded cut stats from ../../output/results/alpha_CRY_signal-LH_aw/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../output/results/alpha_CRY_signal-LH_aw/hists.h5
# [Load] ✅ Loaded efficiency info from ../../output/results/alpha_CRY_signal-LH_aw/efficiency.csv
# [Load] ⚠️ File not found: ../../output/results/alpha_CRY_signal-LH_aw/events.parquet
# [Load] ⚠️ File not found: ../../output/results/alpha_CRY_signal-LH_aw/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                    Cut  Events Passing  Absolute [%]  Relative [%]  \
# 0              No cuts         1474788    100.000000    100.000000
# 1     is_reco_electron         1473016     99.879847     99.879847
# 2        has_trk_front         1473015     99.879779     99.999932
# 3         good_trkqual          799619     54.219250     54.284512
# 4            within_t0          578136     39.201295     72.301434
# 5        is_downstream          578128     39.200753     99.998616
# 6             has_hits          573794     38.906880     99.250339
# 7            within_d0          544501     36.920629     94.894858
# 8   within_pitch_angle          521007     35.327586     95.685224
# 9       within_lhr_max          343354     23.281584     65.901994
# 10   is_truth_electron          343354     23.281584    100.000000
# 11   one_reco_electron          342912     23.251613     99.871270
# 12      within_ext_win          329149     22.318394     95.986434
# 13      within_sig_win          253895     17.215695     77.136798
#
#                                           Description
# 0                                No selection applied
# 1                                 Electron track fits
# 2                   Tracks intersect tracker entrance
# 3                             Track fit quality > 0.8
# 4        t0 at tracker entrance (640 < t_0 < 1650 ns)
# 5     Downstream tracks (p_z > 0 at tracker entrance)
# 6                             >20 active tracker hits
# 7         Distance of closest approach (d_0 < 100 mm)
# 8   Extrapolated pitch angle (0.557735 < tan(theta...
# 9    Loop helix maximum radius (450 < R_max < 680 mm)
# 10            Track parents are electrons (truth PID)
# 11                          One reco electron / event
# 12              Extended window (100 < p < 110 MeV/c)
# 13            Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Histograms

# %%
draw = Draw()

# Define image directory
img_dir = f"../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/alpha_CRY_signal-LH_aw/h1o_1x3_mom_windows.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_zwindows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/alpha_CRY_signal-LH_aw/h1o_crv_zwindows.png

# %% [markdown]
# And it wants to use the full selection, ignoring my slice command

# %% [markdown]
# ### Efficiency

# %%
display(results["efficiency"])
# Out:
#             Type  Events Passing (k)  Total Events (N)  Efficiency [%]  \
# 0  Signal (wide)              342912           4000000            8.57
# 1   Signal (ext)              329149           4000000            8.23
# 2   Signal (sig)              253895           4000000            6.35
# 3    Veto (wide)                   0            342912          100.00
# 4     Veto (ext)                   0            329149          100.00
# 5     Veto (sig)                   0            253895          100.00
#
#    Efficiency Error [%]
# 0                  0.01
# 1                  0.01
# 2                  0.01
# 3                  0.00
# 4                  0.00
# 5                  0.00

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
from pyutils.pyprint import Print
printer = Print()
printer.print_n_events(results["events"], n_events=len(results["events"]))
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 from pyutils.pyprint import Print
#       2 printer = Print()
# ----> 3 printer.print_n_events(results["events"], n_events=len(results["events"]))
#
# TypeError: object of type 'NoneType' has no len()
