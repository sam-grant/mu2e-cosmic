# %% [markdown]
# # Analysis notebook: `SU2020c_signal_onspill-LH_au`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "SU2020c_signal_onspill-LH_au"

# %% [markdown]
# ## Preamble

# %%
import sys
sys.path.append("..")
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../../output/results/SU2020c_signal_onspill-LH_au
# Out:
# analysis.csv  hists.h5	   SU2020c_signal_onspill-LH_au.log
# cut_flow.csv  results.pkl  SU2020c_signal_onspill-LH_au.yaml

# %%
loader = Load(
    in_path = f"../../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../../output/results/SU2020c_signal_onspill-LH_au

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../../output/results/SU2020c_signal_onspill-LH_au/results.pkl
# [Load] ✅ Loaded cut stats from ../../../output/results/SU2020c_signal_onspill-LH_au/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../../output/results/SU2020c_signal_onspill-LH_au/hists.h5
# [Load] ✅ Loaded analysis info from ../../../output/results/SU2020c_signal_onspill-LH_au/analysis.csv
# [Load] ⚠️ File not found: ../../../output/results/SU2020c_signal_onspill-LH_au/events.parquet
# [Load] ⚠️ File not found: ../../../output/results/SU2020c_signal_onspill-LH_au/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                       Cut      Group  Events Passing  Absolute [%]  \
# 0                 No cuts        NaN         1454548       100.000
# 1           has_trk_front  Preselect         1454280        99.982
# 2        is_reco_electron  Preselect         1428881        98.235
# 3           is_downstream  Preselect         1428761        98.227
# 4       one_reco_electron  Preselect         1424823        97.956
# 5       is_truth_electron  Preselect         1424821        97.956
# 6               within_t0    Tracker         1013875        69.704
# 7                has_hits    Tracker          952436        65.480
# 8            within_t0err    Tracker          560947        38.565
# 9               within_d0    Tracker          553225        38.034
# 10  within_pitch_angle_lo    Tracker          553101        38.026
# 11  within_pitch_angle_hi    Tracker          487623        33.524
# 12      within_lhr_max_hi    Tracker          487547        33.519
# 13         within_ext_win   Momentum          460868        31.685
# 14         within_sig_win   Momentum          342136        23.522
#
#     Relative [%]                                      Description
# 0        100.000                             No selection applied
# 1         99.982                Tracks intersect tracker entrance
# 2         98.254                              Electron track fits
# 3         99.992  Downstream tracks (p_z > 0 at tracker entrance)
# 4         99.724                        One reco electron / event
# 5        100.000          Track parents are electrons (truth PID)
# 6         71.158     t0 at tracker entrance (640 < t_0 < 1650 ns)
# 7         93.940                          >20 active tracker hits
# 8         58.896        Track fit t0 uncertainty (t0err < 0.9 ns)
# 9         98.623      Distance of closest approach (d_0 < 100 mm)
# 10        99.978            Extrapolated pitch angle (pz/pt > 0.5
# 11        88.162            Extrapolated pitch angle (pz/pt > 1.0
# 12        99.984       Loop helix maximum radius (R_max < 680 mm)
# 13        94.528            Extended window (100 < p < 110 MeV/c)
# 14        74.237          Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Efficiency & rates

# %%
display(results["analysis"])
# Out:
#                                                  0              1  \
# Type                                CE-like (wide)  CE-like (ext)
# k                                           487547         460868
# N                                          4000000        4000000
# Eff [%]                                     12.189         11.522
# Eff Err$-$ [%]                              -0.016         -0.016
# Eff Err$+$ [%]                               0.016          0.016
# Rate 1B [$\text{day}^{-1}$]               487547.0       460868.0
# Rate 1B Err$-$ [$\text{day}^{-1}$]        -694.379       -675.114
# Rate 1B Err$+$ [$\text{day}^{-1}$]         695.373        676.107
# Rate 2B [$\text{day}^{-1}$]               487547.0       460868.0
# Rate 2B Err$-$ [$\text{day}^{-1}$]        -694.379       -675.114
# Rate 2B Err$+$ [$\text{day}^{-1}$]         695.373        676.107
#
#                                                 2               3  \
# Type                                CE-like (sig)  No veto (wide)
# k                                          342136               0
# N                                         4000000          487547
# Eff [%]                                     8.553           100.0
# Eff Err$-$ [%]                             -0.014            -0.0
# Eff Err$+$ [%]                              0.014             0.0
# Rate 1B [$\text{day}^{-1}$]              342136.0             0.0
# Rate 1B Err$-$ [$\text{day}^{-1}$]       -581.686             0.0
# Rate 1B Err$+$ [$\text{day}^{-1}$]        582.679           1.139
# Rate 2B [$\text{day}^{-1}$]              342136.0             0.0
# Rate 2B Err$-$ [$\text{day}^{-1}$]       -581.686             0.0
# Rate 2B Err$+$ [$\text{day}^{-1}$]        582.679           1.139
#
#                                                 4              5
# Type                                No veto (ext)  No veto (sig)
# k                                               0              0
# N                                          460868         342136
# Eff [%]                                     100.0          100.0
# Eff Err$-$ [%]                               -0.0           -0.0
# Eff Err$+$ [%]                                0.0            0.0
# Rate 1B [$\text{day}^{-1}$]                   0.0            0.0
# Rate 1B Err$-$ [$\text{day}^{-1}$]            0.0            0.0
# Rate 1B Err$+$ [$\text{day}^{-1}$]          1.139          1.139
# Rate 2B [$\text{day}^{-1}$]                   0.0            0.0
# Rate 2B Err$-$ [$\text{day}^{-1}$]            0.0            0.0
# Rate 2B Err$+$ [$\text{day}^{-1}$]          1.139          1.139

# %% [markdown]
# ### Histograms

# %%
# Setup draw for this cutset
on_spill = "offspill" not in ana_label
draw = Draw(cutset_name=ana_label.split('_')[0], on_spill=on_spill)
# Define image directory
img_dir = f"../../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020c_signal_onspill-LH_au/h1o_1x3_mom_windows.png

# %%
draw.plot_summary(results["hists"], out_path=f"{img_dir}/h1o_3x3_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020c_signal_onspill-LH_au/h1o_3x3_summary.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_z.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020c_signal_onspill-LH_au/h1o_crv_z.png

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = len(results["events"]))
