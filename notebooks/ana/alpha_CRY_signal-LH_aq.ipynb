# %% [markdown]
# # Analysis notebook: `alpha_CRY_signal-LH_aq`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "alpha_CRY_signal-LH_aq"

# %% [markdown]
# ## Preamble

# %%
from preamble import *

# %% [markdown]
# # Load data

# %%
# !ls ../../output/results/alpha_CRY_signal-LH_aq
# Out:
# alpha_CRY_signal-LH_aq.log   cut_flow.csv    events.parquet  results.pkl
# alpha_CRY_signal-LH_aq.yaml  efficiency.csv  hists.h5	     stats.csv

# %%
loader = Load(
    in_path = f"../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../output/results/alpha_CRY_signal-LH_aq

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../output/results/alpha_CRY_signal-LH_aq/results.pkl
# [Load] ✅ Loaded cut stats from ../../output/results/alpha_CRY_signal-LH_aq/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../output/results/alpha_CRY_signal-LH_aq/hists.h5
# [Load] ✅ Loaded efficiency info from ../../output/results/alpha_CRY_signal-LH_aq/efficiency.csv
# [Load] ✅ Successfully loaded ak.Array from ../../output/results/alpha_CRY_signal-LH_aq/events.parquet
# [Load] ⚠️ File not found: ../../output/results/alpha_CRY_signal-LH_aq/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                    Cut  Events Passing  Absolute [%]  Relative [%]  \
# 0              No cuts         1475237    100.000000    100.000000
# 1     is_reco_electron         1473988     99.915336     99.915336
# 2        has_trk_front         1449798     98.275599     98.358874
# 3         good_trkqual          792767     53.738281     54.681204
# 4            within_t0          573169     38.852672     72.299806
# 5        is_downstream          573165     38.852401     99.999302
# 6             has_hits          568876     38.561668     99.251699
# 7            within_d0          563926     38.226129     99.129863
# 8   within_pitch_angle          527878     35.782590     93.607672
# 9       within_lhr_max          471743     31.977438     89.365914
# 10   is_truth_electron          471743     31.977438    100.000000
# 11   one_reco_electron          469967     31.857051     99.623524
# 12      within_ext_win          450582     30.543025     95.875242
# 13      within_sig_win          345591     23.426134     76.698803
#
#                                           Description
# 0                                No selection applied
# 1                                 Electron track fits
# 2                   Tracks intersect tracker entrance
# 3                             Track fit quality > 0.8
# 4        t0 at tracker entrance (640 < t_0 < 1650 ns)
# 5     Downstream tracks (p_z > 0 at tracker entrance)
# 6                             >20 active tracker hits
# 7         Distance of closest approach (d_0 < 100 mm)
# 8   Extrapolated pitch angle (0.557735 < tan(theta...
# 9    Loop helix maximum radius (450 < R_max < 680 mm)
# 10            Track parents are electrons (truth PID)
# 11                          One reco electron / event
# 12              Extended window (100 < p < 110 MeV/c)
# 13            Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Histograms

# %%
draw = Draw()

# Define image directory
img_dir = f"../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/alpha_CRY_signal-LH_aq/h1o_1x3_mom_windows.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_zwindows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/alpha_CRY_signal-LH_aq/h1o_crv_zwindows.png

# %% [markdown]
# And it wants to use the full selection, ignoring my slice command

# %% [markdown]
# ### Efficiency

# %%
display(results["efficiency"])
# Out:
#             Type  Events Passing (k)  Total Events (N)  Efficiency [%]  \
# 0  Signal (wide)              469967           4000000           11.75
# 1   Signal (ext)              450582           4000000           11.26
# 2   Signal (sig)              345591           4000000            8.64
# 3    Veto (wide)                   0            469967          100.00
# 4     Veto (ext)                   0            450582          100.00
# 5     Veto (sig)                   0            345591          100.00
#
#    Efficiency Error [%]
# 0                  0.02
# 1                  0.02
# 2                  0.01
# 3                  0.00
# 4                  0.00
# 5                  0.00

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
from pyutils.pyprint import Print
printer = Print()
printer.print_n_events(results["events"], n_events=len(results["events"]))
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 from pyutils.pyprint import Print
#       2 printer = Print()
# ----> 3 printer.print_n_events(results["events"], n_events=len(results["events"]))
#
# TypeError: object of type 'NoneType' has no len()
