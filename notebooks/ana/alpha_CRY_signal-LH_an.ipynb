# %% [markdown]
# # Analysis notebook: `alpha_CRY_signal-LH_an`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "alpha_CRY_signal-LH_an"

# %% [markdown]
# ## Preamble

# %%
from preamble import *

# %% [markdown]
# # Load data

# %%
# !ls ../../output/results/alpha_CRY_signal-LH_an
# Out:
# alpha_CRY_signal-LH_an.log   cut_flow.csv    hists.h5
# alpha_CRY_signal-LH_an.yaml  efficiency.csv  results.pkl

# %%
loader = Load(
    in_path = f"../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../output/results/alpha_CRY_signal-LH_an

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../output/results/alpha_CRY_signal-LH_an/results.pkl
# [Load] ✅ Loaded cut stats from ../../output/results/alpha_CRY_signal-LH_an/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../output/results/alpha_CRY_signal-LH_an/hists.h5
# [Load] ✅ Loaded efficiency info from ../../output/results/alpha_CRY_signal-LH_an/efficiency.csv
# [Load] ⚠️ File not found: ../../output/results/alpha_CRY_signal-LH_an/events.parquet
# [Load] ⚠️ File not found: ../../output/results/alpha_CRY_signal-LH_an/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                    Cut  Events Passing  Absolute [%]  Relative [%]  \
# 0              No cuts         1479285    100.000000    100.000000
# 1     is_reco_electron         1475995     99.777595     99.777595
# 2        has_trk_front         1450562     98.058319     98.276891
# 3         good_trkqual          785562     53.104169     54.155700
# 4            within_t0          567817     38.384557     72.281628
# 5        is_downstream          567812     38.384219     99.999119
# 6             has_hits          563443     38.088874     99.230555
# 7            within_d0          561129     37.932447     99.589311
# 8   within_pitch_angle          523520     35.390070     93.297620
# 9       within_lhr_max          522878     35.346671     99.877369
# 10   is_truth_electron          522878     35.346671    100.000000
# 11   one_reco_electron          522321     35.309018     99.893474
# 12      within_ext_win          499014     33.733459     95.537801
# 13      within_sig_win          382596     25.863576     76.670394
#
#                                           Description
# 0                                No selection applied
# 1                                 Electron track fits
# 2                   Tracks intersect tracker entrance
# 3                             Track fit quality > 0.8
# 4        t0 at tracker entrance (640 < t_0 < 1650 ns)
# 5     Downstream tracks (p_z > 0 at tracker entrance)
# 6                             >20 active tracker hits
# 7         Distance of closest approach (d_0 < 100 mm)
# 8   Extrapolated pitch angle (0.557735 < tan(theta...
# 9    Loop helix maximum radius (450 < R_max < 680 mm)
# 10            Track parents are electrons (truth PID)
# 11                          One reco electron / event
# 12              Extended window (100 < p < 110 MeV/c)
# 13            Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Histograms

# %%
draw = Draw()

# Define image directory
img_dir = f"../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/alpha_CRY_signal-LH_an/h1o_1x3_mom_windows.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_zwindows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/alpha_CRY_signal-LH_an/h1o_crv_zwindows.png

# %% [markdown]
# And it wants to use the full selection, ignoring my slice command

# %% [markdown]
# ### Efficiency

# %%
display(results["efficiency"])
# Out:
#             Type  Events Passing (k)  Total Events (N)  Efficiency [%]  \
# 0  Signal (wide)              522321           4000000           13.06
# 1   Signal (ext)              499014           4000000           12.48
# 2   Signal (sig)              382596           4000000            9.56
# 3    Veto (wide)                   0            522321          100.00
# 4     Veto (ext)                   0            499014          100.00
# 5     Veto (sig)                   0            382596          100.00
#
#    Efficiency Error [%]
# 0                  0.02
# 1                  0.02
# 2                  0.01
# 3                  0.00
# 4                  0.00
# 5                  0.00

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
from pyutils.pyprint import Print
printer = Print()
printer.print_n_events(results["events"], n_events=len(results["events"]))
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 from pyutils.pyprint import Print
#       2 printer = Print()
# ----> 3 printer.print_n_events(results["events"], n_events=len(results["events"]))
#
# TypeError: object of type 'NoneType' has no len()
