# %% [markdown]
# # Analysis notebook: `SU2020a_signal_onspill-LH_aw`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "SU2020a_signal_onspill-LH_aw"

# %% [markdown]
# ## Preamble

# %%
import sys
sys.path.append("..")
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../../output/results/SU2020a_signal_onspill-LH_aw
# Out:
# analysis.csv  hists.h5	   SU2020a_signal_onspill-LH_aw.log
# cut_flow.csv  results.pkl  SU2020a_signal_onspill-LH_aw.yaml

# %%
loader = Load(
    in_path = f"../../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../../output/results/SU2020a_signal_onspill-LH_aw

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../../output/results/SU2020a_signal_onspill-LH_aw/results.pkl
# [Load] ✅ Loaded cut stats from ../../../output/results/SU2020a_signal_onspill-LH_aw/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../../output/results/SU2020a_signal_onspill-LH_aw/hists.h5
# [Load] ✅ Loaded analysis info from ../../../output/results/SU2020a_signal_onspill-LH_aw/analysis.csv
# [Load] ⚠️ File not found: ../../../output/results/SU2020a_signal_onspill-LH_aw/events.parquet
# [Load] ⚠️ File not found: ../../../output/results/SU2020a_signal_onspill-LH_aw/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"].round(3))
# Out:
#                       Cut      Group  Events Passing  Absolute [%]  \
# 0                 No cuts        NaN         1474788       100.000
# 1           has_trk_front  Preselect         1474432        99.976
# 2        is_reco_electron  Preselect         1473015        99.880
# 3           is_downstream  Preselect         1473003        99.879
# 4       one_reco_electron  Preselect         1468842        99.597
# 5       is_truth_electron  Preselect         1468840        99.597
# 6            good_trkqual    Tracker          798612        54.151
# 7               within_t0    Tracker          577416        39.152
# 8                has_hits    Tracker          573088        38.859
# 9            within_t0err    Tracker           34865         2.364
# 10              within_d0    Tracker           27750         1.882
# 11  within_pitch_angle_lo    Tracker           27697         1.878
# 12  within_pitch_angle_hi    Tracker           16242         1.101
# 13      within_lhr_max_hi    Tracker           16184         1.097
# 14         within_ext_win   Momentum           15077         1.022
# 15         within_sig_win   Momentum           11926         0.809
#
#     Relative [%]                                      Description
# 0        100.000                             No selection applied
# 1         99.976                Tracks intersect tracker entrance
# 2         99.904                              Electron track fits
# 3         99.999  Downstream tracks (p_z > 0 at tracker entrance)
# 4         99.718                        One reco electron / event
# 5        100.000          Track parents are electrons (truth PID)
# 6         54.370                          Track fit quality > 0.8
# 7         72.302     t0 at tracker entrance (640 < t_0 < 1650 ns)
# 8         99.250                          >20 active tracker hits
# 9          6.084        Track fit t0 uncertainty (t0err < 0.9 ns)
# 10        79.593      Distance of closest approach (d_0 < 100 mm)
# 11        99.809           Extrapolated pitch angle (pz/pt > 0.5)
# 12        58.642           Extrapolated pitch angle (pz/pt < 1.0)
# 13        99.643       Loop helix maximum radius (R_max < 680 mm)
# 14        93.160            Extended window (100 < p < 110 MeV/c)
# 15        79.101          Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Efficiency & rates

# %%
display(results["analysis"].round(3))
# Out:
# 0                                 Type CE-like (wide) CE-like (ext)  \
# 0                                    k          16184         15077
# 1                                    N        4000000       4000000
# 2                              Eff [%]         0.4046      0.376925
# 3                       Eff Err$-$ [%]      -0.003162     -0.003052
# 4                       Eff Err$+$ [%]       0.003186      0.003076
# 5          Rate 1B [$\text{day}^{-1}$]        16184.0       15077.0
# 6   Rate 1B Err$-$ [$\text{day}^{-1}$]    -126.513682    -122.11026
# 7   Rate 1B Err$+$ [$\text{day}^{-1}$]     127.510223    123.106941
# 8          Rate 2B [$\text{day}^{-1}$]        16184.0       15077.0
# 9   Rate 2B Err$-$ [$\text{day}^{-1}$]    -126.513682    -122.11026
# 10  Rate 2B Err$+$ [$\text{day}^{-1}$]     127.510223    123.106941
#
# 0  CE-like (sig) No veto (wide) No veto (ext) No veto (sig)
# 0          11926              0             0             0
# 1        4000000          16184         15077         11926
# 2        0.29815          100.0         100.0         100.0
# 3      -0.002714      -0.006179     -0.006632     -0.008384
# 4       0.002739            0.0           0.0           0.0
# 5        11926.0            0.0           0.0           0.0
# 6    -108.603157            0.0           0.0           0.0
# 7     109.600342       1.139434      1.139434      1.139434
# 8        11926.0            0.0           0.0           0.0
# 9    -108.603157            0.0           0.0           0.0
# 10    109.600342       1.139434      1.139434      1.139434

# %% [markdown]
# ### Histograms

# %%
# Setup draw for this cutset
on_spill = "offspill" not in ana_label
draw = Draw(cutset_name=ana_label.split('_')[0], on_spill=on_spill)
# Define image directory
img_dir = f"../../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020a_signal_onspill-LH_aw/h1o_1x3_mom_windows.png

# %%
draw.plot_summary(results["hists"], out_path=f"{img_dir}/h1o_3x3_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020a_signal_onspill-LH_aw/h1o_3x3_summary.png

# %%
draw.plot_mom_summary(results["hists"], out_path=f"{img_dir}/h1o_2x2_mom_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020a_signal_onspill-LH_aw/h1o_2x2_mom_summary.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_z.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020a_signal_onspill-LH_aw/h1o_crv_z.png

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = len(results["events"]))
