# %% [markdown]
# # Analysis notebook: `alpha_CRY_signal-LH_au`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "alpha_CRY_signal-LH_au"

# %% [markdown]
# ## Preamble

# %%
from preamble import *

# %% [markdown]
# # Load data

# %%
# !ls ../../output/results/alpha_CRY_signal-LH_au
# Out:
# alpha_CRY_signal-LH_au.log   cut_flow.csv    hists.h5
# alpha_CRY_signal-LH_au.yaml  efficiency.csv  results.pkl

# %%
loader = Load(
    in_path = f"../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../output/results/alpha_CRY_signal-LH_au

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../output/results/alpha_CRY_signal-LH_au/results.pkl
# [Load] ✅ Loaded cut stats from ../../output/results/alpha_CRY_signal-LH_au/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../output/results/alpha_CRY_signal-LH_au/hists.h5
# [Load] ✅ Loaded efficiency info from ../../output/results/alpha_CRY_signal-LH_au/efficiency.csv
# [Load] ⚠️ File not found: ../../output/results/alpha_CRY_signal-LH_au/events.parquet
# [Load] ⚠️ File not found: ../../output/results/alpha_CRY_signal-LH_au/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                    Cut  Events Passing  Absolute [%]  Relative [%]  \
# 0              No cuts         2189973    100.000000    100.000000
# 1     is_reco_electron         2116233     96.632835     96.632835
# 2        has_trk_front         2098551     95.825428     99.164459
# 3         good_trkqual          369869     16.889204     17.624971
# 4            within_t0          301192     13.753229     81.432075
# 5        is_downstream          214801      9.808386     71.316967
# 6             has_hits          214240      9.782769     99.738828
# 7            within_d0           77473      3.537624     36.161781
# 8   within_pitch_angle           42365      1.934499     54.683567
# 9       within_lhr_max           34031      1.553946     80.328101
# 10   is_truth_electron           21408      0.977546     62.907349
# 11   one_reco_electron           11961      0.546171     55.871637
# 12      within_ext_win            1590      0.072604     13.293203
# 13      within_sig_win             165      0.007534     10.377358
#
#                                           Description
# 0                                No selection applied
# 1                                 Electron track fits
# 2                   Tracks intersect tracker entrance
# 3                             Track fit quality > 0.8
# 4        t0 at tracker entrance (640 < t_0 < 1650 ns)
# 5     Downstream tracks (p_z > 0 at tracker entrance)
# 6                             >20 active tracker hits
# 7         Distance of closest approach (d_0 < 100 mm)
# 8   Extrapolated pitch angle (0.557735 < tan(theta...
# 9    Loop helix maximum radius (450 < R_max < 680 mm)
# 10            Track parents are electrons (truth PID)
# 11                          One reco electron / event
# 12              Extended window (100 < p < 110 MeV/c)
# 13            Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Histograms

# %%
draw = Draw()

# Define image directory
img_dir = f"../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/alpha_CRY_signal-LH_au/h1o_1x3_mom_windows.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_zwindows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/alpha_CRY_signal-LH_au/h1o_crv_zwindows.png

# %% [markdown]
# And it wants to use the full selection, ignoring my slice command

# %% [markdown]
# ### Efficiency

# %%
display(results["efficiency"])
# Out:
#             Type  Events Passing (k)  Total Events (N)  Efficiency [%]  \
# 0  Signal (wide)               11961           4000000            0.30
# 1   Signal (ext)                1590           4000000            0.04
# 2   Signal (sig)                 165           4000000            0.00
# 3    Veto (wide)                   0             11961          100.00
# 4     Veto (ext)                   0              1590          100.00
# 5     Veto (sig)                   0               165          100.00
#
#    Efficiency Error [%]
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.03
# 5                  0.30

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
from pyutils.pyprint import Print
printer = Print()
printer.print_n_events(results["events"], n_events=len(results["events"]))
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 from pyutils.pyprint import Print
#       2 printer = Print()
# ----> 3 printer.print_n_events(results["events"], n_events=len(results["events"]))
#
# TypeError: object of type 'NoneType' has no len()
