# %% [markdown]
# # Analysis notebook: `test`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "test"

# %% [markdown]
# ## Preamble

# %%
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../output/results/test
# Out:
# cut_flow.csv  efficiency.csv  hists.h5	results.pkl  test.log  test.yaml

# %%
loader = Load(
    in_path = f"../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../output/results/test

# %%
results = loader.load_pkl()
# Out:
# [Load] ✅ Successfully loaded results from ../../output/results/test/results.pkl

# %%
draw = Draw()

# # Define image directory
# img_dir = f"../../output/images/{ana_label}"
# os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
# draw.plot_mom_windows(results["hists"], out_path=None)

# %%
# draw.plot_crv_z(results["hists"], out_path=None)

# %%
results["hists"]
# Out:
# {'mom_full': Hist(
#    Regular(30, 0, 300, name='mom', label='Momentum [MeV/c]'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 10423.0 (10501.0 with flow),
#  'mom_ext': Hist(
#    Regular(10, 100, 110, name='mom', label='Momentum [MeV/c]'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 591.0,
#  'mom_sig': Hist(
#    Regular(13, 103.6, 104.9, name='mom', label='Momentum [MeV/c]'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 80.0,
#  'crv_z': Hist(
#    Regular(100, -15000, 10000, name='crv_z', label='CRV z-position [mm]'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 7694.0,
#  'trkqual': Hist(
#    Regular(100, 0, 1, name='trkqual', label='Track quality'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='90'),
#    storage=Double()) # Sum: 9148.0,
#  'nactive': Hist(
#    Regular(100, 0, 100, name='nactive', label='Active tracker hits'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 9069.0 (9148.0 with flow),
#  't0err': Hist(
#    Regular(100, 0, 3, name='t0err', label='Track $t_{0}$ uncertainty, $\\sigma_{t_{0}}$ [ns]'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 9762.0 (10501.0 with flow),
#  'maxr': Hist(
#    Regular(150, 200, 850, name='maxr', label='Loop helix maximum radius, $R_{\\text{max}}$ [mm]'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 10170.0 (10501.0 with flow),
#  'd0': Hist(
#    Regular(350, -50, 500, name='d0', label='Distance of closest approach, $d_{0}$ [mm]'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 10256.0 (10501.0 with flow),
#  'pitch_angle': Hist(
#    Regular(150, -0.5, 2.5, name='pitch_angle', label='Pitch angle, $p_{z}/p_{T}$'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 6245.0 (10501.0 with flow),
#  'pdg': Hist(
#    Regular(30, -15, 15, name='pdg', label='Track PDG'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 9148.0,
#  'sid': Hist(
#    Regular(60, -10, 50, name='sid', label='Surface ID'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 10501.0,
#  'pz': Hist(
#    Regular(110, -10, 100, name='pz', label='$p_{z}$ [MeV/c]'),
#    StrCategory(['All', 'CE-like', 'Unvetoed'], name='selection', label='Selection'),
#    storage=Double()) # Sum: 4508.0 (10501.0 with flow)}

# %%
help(draw)
# Out:
# Help on Draw in module draw object:
#
# class Draw(builtins.object)
#  |  Draw(cutset_name='alpha', verbosity=1)
#  |
#  |  Class to draw standard "hist" histograms produced by Analyse().create_histograms()
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, cutset_name='alpha', verbosity=1)
#  |      Initialise
#  |
#  |      Args:
#  |          cutset_name (str, opt): The cutset name. Defaults to 'alpha'.
#  |          verbosity (int, optional): Level of output detail (0: critical errors only, 1: info, 2: debug, 3: deep debug)
#  |
#  |  plot_crv_z(self, hists, out_path=None)
#  |      Plot CRV z-position histograms
#  |
#  |  plot_mom_windows(self, hists, out_path=None)
#  |      Plot 1x3 momentum window histograms
#  |
#  |  plot_sanity(self, hists, out_path=None)
#  |      Plot 1x3 sanity histograms
#  |
#  |  plot_trk_params(self, hists, out_path=None)
#  |      Plot 1x2 track-level histograms
#  |
#  |  plot_trkfit_params(self, hists, out_path=None)
#  |      Plot 2x2 trackfit-level histograms
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
draw.plot_trk_params(results["hists"])

# %%
# draw.plot_trk_params(results["hists"])

# %%
draw.plot_trkfit_params(results["hists"])

# %%
draw.plot_sanity(results["hists"])
