# %% [markdown]
# # Analysis notebook: `SU2020_CRY_onspill-LH_aw`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "SU2020_CRY_onspill-LH_aw"

# %% [markdown]
# ## Preamble

# %%
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../output/results/SU2020_CRY_onspill-LH_aw
# Out:
# cut_flow.csv	events.parquet	info.txt     SU2020_CRY_onspill-LH_aw.log
# efficiency.csv	hists.h5	results.pkl  SU2020_CRY_onspill-LH_aw.yaml

# %%
loader = Load(
    in_path = f"../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../output/results/SU2020_CRY_onspill-LH_aw

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../output/results/SU2020_CRY_onspill-LH_aw/results.pkl
# [Load] ✅ Loaded cut stats from ../../output/results/SU2020_CRY_onspill-LH_aw/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../output/results/SU2020_CRY_onspill-LH_aw/hists.h5
# [Load] ✅ Loaded efficiency info from ../../output/results/SU2020_CRY_onspill-LH_aw/efficiency.csv
# [Load] ✅ Successfully loaded ak.Array from ../../output/results/SU2020_CRY_onspill-LH_aw/events.parquet
# [Load] ✅ Loaded info from ../../output/results/SU2020_CRY_onspill-LH_aw/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"])
# Out:
#                    Cut  Events Passing  Absolute [%]  Relative [%]  \
# 0              No cuts         2529740    100.000000    100.000000
# 1     is_reco_electron         2442213     96.540079     96.540079
# 2        has_trk_front         2399747     94.861409     98.261167
# 3         good_trkqual          377984     14.941615     15.750994
# 4            within_t0          307816     12.167891     81.436251
# 5        is_downstream          221797      8.767581     72.055059
# 6             has_hits          221088      8.739554     99.680338
# 7         within_t0err          180170      7.122076     81.492437
# 8            within_d0           36395      1.438685     20.200366
# 9   within_pitch_angle           13299      0.525706     36.540734
# 10   within_lhr_max_hi           10731      0.424194     80.690277
# 11   is_truth_electron            6966      0.275364     64.914733
# 12   one_reco_electron            3170      0.125309     45.506747
# 13            unvetoed               2      0.000079      0.063091
# 14      within_ext_win               0      0.000000      0.000000
# 15      within_sig_win               0      0.000000      0.000000
#
#                                           Description
# 0                                No selection applied
# 1                                 Electron track fits
# 2                   Tracks intersect tracker entrance
# 3                             Track fit quality > 0.8
# 4        t0 at tracker entrance (640 < t_0 < 1650 ns)
# 5     Downstream tracks (p_z > 0 at tracker entrance)
# 6                             >20 active tracker hits
# 7           Track fit t0 uncertainty (t0err < 0.9 ns)
# 8         Distance of closest approach (d_0 < 100 mm)
# 9   Extrapolated pitch angle (0.5 < tan(theta_Dip)...
# 10         Loop helix maximum radius (R_max < 680 mm)
# 11            Track parents are electrons (truth PID)
# 12                          One reco electron / event
# 13                            No veto: |dt| >= 150 ns
# 14              Extended window (100 < p < 110 MeV/c)
# 15            Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Histograms

# %%
draw = Draw()

# Define image directory
img_dir = f"../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/SU2020_CRY_onspill-LH_aw/h1o_1x3_mom_windows.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_zwindows.png")
# Out:
# [Plot] ✅ 	Wrote ../../output/images/SU2020_CRY_onspill-LH_aw/h1o_crv_zwindows.png

# %%
draw.plot_trk_params(results["hists"])

# %%
# draw.plot_trkfit_params(results["hists"])
draw.plot_trkfit_params_SU2020(results["hists"])

# %% [markdown]
# ### Efficiency

# %%
display(results["efficiency"])
# Out:
#             Type  Events Passing (k)  Total Events (N)  Efficiency [%]  \
# 0  Signal (wide)                3170           4000000            0.08
# 1   Signal (ext)                 510           4000000            0.01
# 2   Signal (sig)                  59           4000000            0.00
# 3    Veto (wide)                   2              3170           99.94
# 4     Veto (ext)                   0               510          100.00
# 5     Veto (sig)                   0                59          100.00
#
#    Efficiency Error [%]
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.05
# 4                  0.10
# 5                  0.83

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
#   Index:            20
#   Subrun:           [3113]
#   Event:            [86303]
#   File:             nts.mu2e.CosmicCRYSignalAllOnSpillTriggered.MDC2020aw_best_v1_3_v06_05_00.001202_00000034.root
#   Track time [ns]:  1004.101804
#   Coinc time [ns]:  853.986267
#   dt [ns]:          150.115536
# ----------------------------------------
#   Index:            200
#   Subrun:           [19742]
#   Event:            [359830]
#   File:             nts.mu2e.CosmicCRYSignalAllOnSpillTriggered.MDC2020aw_best_v1_3_v06_05_00.001202_00015581.root
#   Track time [ns]:  822.773672
#   Coinc time [ns]:  None
#   dt [ns]:          N/A
# ----------------------------------------

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = len(results["events"]))
# Out:
# [pyprint] ⭐️ Initialised Print with verbose = False and precision = 1
# [pyprint] ⭐️ Printing 2 event(s)...
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 3113
# evt.event: 86303
# crv.crvcoincs.time: [854]
# crv.crvcoincs.nHits: [18]
# crv.crvcoincs.pos.fCoordinates.fZ: [2.56e+03]
# is_reco_electron: [True, False]
# at_trk_front: [[False, False, False, True, False, False], [False, False, ..., False]]
# has_trk_front: [True, True]
# good_trkqual: [True, False]
# within_t0: [True, True]
# is_downstream: [True, True]
# has_hits: [True, True]
# within_t0err: [True, True]
# within_d0: [True, True]
# within_pitch_angle: [True, True]
# within_lhr_max: [True, True]
# within_lhr_max_hi: [True, True]
# is_truth_electron: [True, True]
# one_reco_electron: [True, True]
# one_reco_electron_per_event: True
# unvetoed: [True, False]
# within_ext_win: [False, False]
# within_sig_win: [False, False]
# CE_like: [True, False]
# unvetoed_CE_like: [True, False]
# trk.trk.nactive: [59]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.948]
# trkfit.trksegs.mom.fCoordinates.fX: [[73.1, -79, 68.5, 46.8, 68.3, 65.4]]
# trkfit.trksegs.mom.fCoordinates.fY: [[42.3, 29.8, 41.6, 63.4, 36.8, -39.4]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[28.9, 28.7, 38.9, 41.3, 42.2, 43.2]]
# trkfit.trksegs.pos.fCoordinates.fX: [[-190, -228, -194, -129, -218, -477]]
# trkfit.trksegs.pos.fCoordinates.fY: [[-232, 195, -229, -182, -258, -258]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-3.04e+03, -2.86e+03, -2.47e+03, -1.63e+03, 10.1, 1.64e+03]]
# trkfit.trksegs.time: [[992, 994, 998, 1e+03, 1.02e+03, 1.03e+03]]
# trkfit.trksegs.dmom: [[-0.0857, -0.0852, -0.0891, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.0662, 0.0653, 0.0644, 0.0634, 0.0611, 0.0602]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False, False]]
# trkfit.trksegs.early: [[True, False, False, False, False, False]]
# trkfit.trksegs.late: [[False, False, False, False, False, True]]
# trkfit.trksegs.sid: [[90, 90, 90, 0, 1, 2]]
# trkfit.trksegs.sindex: [[0, 0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[613, 586, 587, 597, 594, 599]]
# trkfit.trksegpars_lh.d0: [[125, 110, 114, 84.8, 86, 85.4]]
# trkfit.trksegpars_lh.tanDip: [[0.424, 0.372, 0.322, 0.544, 0.524, 0.567]]
# trkfit.trksegpars_lh.rad: [[244, 238, 236, 256, 254, 257]]
# trkfit.trksegpars_lh.lam: [[111, 84.9, 76.5, 138, 132, 145]]
# trkfit.trksegpars_lh.cx: [[-363, -348, -344, -339, -338, -341]]
# trkfit.trksegpars_lh.cy: [[-70.1, 1.68, -69.6, -32.3, -36.1, -35.5]]
# trkfit.trksegpars_lh.phi0: [[-2.4, -1.3, 2.53, 0.416, 0.724, 0.699]]
# trkfit.trksegpars_lh.t0: [[1.02e+03, 1.02e+03, 1.03e+03, 1.02e+03, 1.02e+03, 1.02e+03]]
# trkfit.trksegpars_lh.raderr: [[1.02, 0.588, 0.593, 0.287, 0.632, 0.604]]
# trkfit.trksegpars_lh.lamerr: [[2.19, 1.57, 1.75, 0.256, 1.16, 1.03]]
# trkfit.trksegpars_lh.cxerr: [[2.92, 2.08, 2.1, 0.878, 1.25, 0.646]]
# trkfit.trksegpars_lh.cyerr: [[4.34, 1.03, 2.64, 0.281, 0.899, 1.52]]
# trkfit.trksegpars_lh.phi0err: [[0.317, 0.534, 0.785, 0.00225, 0.0883, 0.0736]]
# trkfit.trksegpars_lh.t0err: [[0.245, 0.655, 0.816, 0.408, 0.416, 0.414]]
# trkmc.trkmcsim.valid: [[True, True, True, True]]
# trkmc.trkmcsim.id: [[9, 0, 10, 0]]
# trkmc.trkmcsim.nhits: [[60, -1, 3, -1]]
# trkmc.trkmcsim.nactive: [[59, -1, 0, -1]]
# trkmc.trkmcsim.rank: [[0, -1, 1, -1]]
# trkmc.trkmcsim.pdg: [[11, 13, 11, 13]]
# trkmc.trkmcsim.startCode: [[14, 56, 31, 56]]
# trkmc.trkmcsim.stopCode: [[17, 54, 17, 54]]
# trkmc.trkmcsim.gen: [[-1, 38, -1, 38]]
# trkmc.trkmcsim.time: [[3.15e+04, 3.13e+04, 3.15e+04, 3.13e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2, 3]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[73.6, -30.3, 0.32, -30.3]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-28.8, -1.3e+03, -0.844, -1.3e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[40.9, -259, -0.194, -259]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[-421, -386, -505, -386]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[-268, 1.54e+04, -196, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-1.81e+03, 5.1e+03, -1.51e+03, 5.1e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[-0, 12.2, 0, 12.2]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[-0, -488, -0, -488]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, -88.6, 0, -88.6]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-358, -839, -506, -839]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[-293, 997, -201, 997]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.68e+03, 2.19e+03, -797, 2.19e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, 0, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, 0, -1]]
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# evt.run: 1202
# evt.subrun: 19742
# evt.event: 359830
# crv.crvcoincs.time: []
# crv.crvcoincs.nHits: []
# crv.crvcoincs.pos.fCoordinates.fZ: []
# is_reco_electron: [True, False, False, False]
# at_trk_front: [[False, False, True, False, False], ..., [False, False, ..., False, True]]
# has_trk_front: [True, True, True, True]
# good_trkqual: [True, False, False, False]
# within_t0: [True, True, True, True]
# is_downstream: [True, False, True, False]
# has_hits: [True, True, True, True]
# within_t0err: [True, True, True, False]
# within_d0: [True, True, True, True]
# within_pitch_angle: [True, False, True, False]
# within_lhr_max: [True, True, True, False]
# within_lhr_max_hi: [True, True, True, False]
# is_truth_electron: [True, True, True, True]
# one_reco_electron: [True, True, True, True]
# one_reco_electron_per_event: True
# unvetoed: [True, True, True, True]
# within_ext_win: [False, False, False, False]
# within_sig_win: [False, False, False, False]
# CE_like: [True, False, False, False]
# unvetoed_CE_like: [True, False, False, False]
# trk.trk.nactive: [51]
# trk.trk.pdg: [11]
# trk.trkqual.valid: [True]
# trk.trkqual.result: [0.971]
# trkfit.trksegs.mom.fCoordinates.fX: [[77.7, -121, -113, -105, -101]]
# trkfit.trksegs.mom.fCoordinates.fY: [[98.6, 30.6, 9.65, -36.4, -41.1]]
# trkfit.trksegs.mom.fCoordinates.fZ: [[50.6, 52.4, 73.5, 75.9, 77.8]]
# trkfit.trksegs.pos.fCoordinates.fX: [[23.2, -168, -230, -388, -415]]
# trkfit.trksegs.pos.fCoordinates.fY: [[-299, 249, 275, 254, 251]]
# trkfit.trksegs.pos.fCoordinates.fZ: [[-3.21e+03, -2.93e+03, -1.63e+03, 10.1, 1.64e+03]]
# trkfit.trksegs.time: [[811, 814, 823, 833, 842]]
# trkfit.trksegs.dmom: [[-0.113, -0.112, 0, 0, 0]]
# trkfit.trksegs.momerr: [[0.0952, 0.0942, 0.0931, 0.0901, 0.0886]]
# trkfit.trksegs.inbounds: [[True, True, True, True, True]]
# trkfit.trksegs.gap: [[False, False, False, False, False]]
# trkfit.trksegs.early: [[True, False, False, False, False]]
# trkfit.trksegs.late: [[False, False, False, False, True]]
# trkfit.trksegs.sid: [[90, 90, 0, 1, 2]]
# trkfit.trksegs.sindex: [[0, 0, 0, 0, 0]]
# trkfit.trksegpars_lh.maxr: [[631, 637, 648, 643, 654]]
# trkfit.trksegpars_lh.d0: [[67, 51.5, 82.6, 84.4, 78.7]]
# trkfit.trksegpars_lh.tanDip: [[0.427, 0.383, 0.684, 0.651, 0.712]]
# trkfit.trksegpars_lh.rad: [[349, 344, 365, 364, 366]]
# trkfit.trksegpars_lh.lam: [[151, 132, 251, 238, 262]]
# trkfit.trksegpars_lh.cx: [[-277, -245, -268, -266, -274]]
# trkfit.trksegpars_lh.cy: [[-51.4, -160, -91.4, -84.1, -88.7]]
# trkfit.trksegpars_lh.phi0: [[-2.94, 0.0641, -2.85, -2.66, -2.73]]
# trkfit.trksegpars_lh.t0: [[838, 841, 833, 833, 833]]
# trkfit.trksegpars_lh.raderr: [[0.615, 0.644, 0.465, 0.703, 0.557]]
# trkfit.trksegpars_lh.lamerr: [[1.31, 1.57, 0.486, 1.01, 0.724]]
# trkfit.trksegpars_lh.cxerr: [[5.63, 4.22, 0.838, 0.997, 1.14]]
# trkfit.trksegpars_lh.cyerr: [[5.64, 1.61, 0.332, 0.794, 0.621]]
# trkfit.trksegpars_lh.phi0err: [[0.194, 0.284, 0.00177, 0.0257, 0.00962]]
# trkfit.trksegpars_lh.t0err: [[0.542, 0.585, 0.427, 0.427, 0.427]]
# trkmc.trkmcsim.valid: [[True, True, True, True, True]]
# trkmc.trkmcsim.id: [[4, 3, 2, 0, 0]]
# trkmc.trkmcsim.nhits: [[51, -1, -1, -1, -1]]
# trkmc.trkmcsim.nactive: [[51, -1, -1, -1, -1]]
# trkmc.trkmcsim.rank: [[0, -1, -1, -1, -1]]
# trkmc.trkmcsim.pdg: [[11, 22, 111, 2112, 2112]]
# trkmc.trkmcsim.startCode: [[13, 14, 97, 56, 56]]
# trkmc.trkmcsim.stopCode: [[17, 13, 14, 54, 54]]
# trkmc.trkmcsim.gen: [[-1, -1, -1, 38, 38]]
# trkmc.trkmcsim.time: [[3.13e+04, 3.13e+04, 3.13e+04, 3.13e+04, 3.13e+04]]
# trkmc.trkmcsim.index: [[0, 1, 2, 3, 4]]
# trkmc.trkmcsim.mom.fCoordinates.fX: [[50.6, 51.9, -17.6, 207, 207]]
# trkmc.trkmcsim.mom.fCoordinates.fY: [[-948, -963, -2.3e+03, -4.92e+03, -4.92e+03]]
# trkmc.trkmcsim.mom.fCoordinates.fZ: [[-27.4, -28.6, 4.27, -711, -711]]
# trkmc.trkmcsim.pos.fCoordinates.fX: [[-746, -771, -771, -1.42e+03, -1.42e+03]]
# trkmc.trkmcsim.pos.fCoordinates.fY: [[608, 1.06e+03, 1.06e+03, 1.54e+04, 1.54e+04]]
# trkmc.trkmcsim.pos.fCoordinates.fZ: [[-3.9e+03, -3.89e+03, -3.89e+03, -1.9e+03, -1.9e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fX: [[0, 51.9, -17.6, 285, 285]]
# trkmc.trkmcsim.endmom.fCoordinates.fY: [[0, -963, -2.3e+03, -4.94e+03, -4.94e+03]]
# trkmc.trkmcsim.endmom.fCoordinates.fZ: [[-0, -28.6, 4.27, -579, -579]]
# trkmc.trkmcsim.endpos.fCoordinates.fX: [[-521, -746, -771, -770, -770]]
# trkmc.trkmcsim.endpos.fCoordinates.fY: [[171, 608, 1.06e+03, 1.05e+03, 1.05e+03]]
# trkmc.trkmcsim.endpos.fCoordinates.fZ: [[1.73e+03, -3.9e+03, -3.89e+03, -3.89e+03, -3.89e+03]]
# trkmc.trkmcsim.prirel._rel: [[-1, -1, -1, -1, 0]]
# trkmc.trkmcsim.prirel._rem: [[-1, -1, -1, -1, 0]]
# trkmc.trkmcsim.trkrel._rel: [[0, 2, 5, 5, -1]]
# trkmc.trkmcsim.trkrel._rem: [[0, 1, 2, 3, -1]]
# -------------------------------------------------------------------------------------
