# %% [markdown]
# # Analysis notebook: `SU2020b_signal_onspill-LH_au`

# %% [markdown]
# ## Define analysis name

# %%
ana_label = "SU2020b_signal_onspill-LH_au"

# %% [markdown]
# ## Preamble

# %%
import sys
sys.path.append("..")
from preamble import *

# %% [markdown]
# ## Load data

# %%
# !ls ../../../output/results/SU2020b_signal_onspill-LH_au
# Out:
# analysis.csv  hists.h5	   SU2020b_signal_onspill-LH_au.log
# cut_flow.csv  results.pkl  SU2020b_signal_onspill-LH_au.yaml

# %%
loader = Load(
    in_path = f"../../../output/results/{ana_label}"
)
# Out:
# [Load] ✅ Initialised with out_path=../../../output/results/SU2020b_signal_onspill-LH_au

# %%
results = loader.load_pkl() 
results_from_persistent = loader.load_all() # Persistent backup
# Out:
# [Load] ✅ Successfully loaded results from ../../../output/results/SU2020b_signal_onspill-LH_au/results.pkl
# [Load] ✅ Loaded cut stats from ../../../output/results/SU2020b_signal_onspill-LH_au/cut_flow.csv
# [Load] ✅ Loaded histograms from ../../../output/results/SU2020b_signal_onspill-LH_au/hists.h5
# [Load] ✅ Loaded analysis info from ../../../output/results/SU2020b_signal_onspill-LH_au/analysis.csv
# [Load] ⚠️ File not found: ../../../output/results/SU2020b_signal_onspill-LH_au/events.parquet
# [Load] ⚠️ File not found: ../../../output/results/SU2020b_signal_onspill-LH_au/info.txt

# %% [markdown]
# ## Analyse results

# %% [markdown]
# ### Cut flow

# %%
display(results["cut_flow"].round(3))
# Out:
#                       Cut      Group  Events Passing  Absolute [%]  \
# 0                 No cuts        NaN         1454548       100.000
# 1           has_trk_front  Preselect         1454280        99.982
# 2        is_reco_electron  Preselect         1428881        98.235
# 3           is_downstream  Preselect         1428761        98.227
# 4       one_reco_electron  Preselect         1424823        97.956
# 5       is_truth_electron  Preselect         1424821        97.956
# 6            good_trkqual    Tracker         1253384        86.170
# 7               within_t0    Tracker          901342        61.967
# 8                has_hits    Tracker          880385        60.526
# 9            within_t0err    Tracker          513744        35.320
# 10              within_d0    Tracker          506934        34.852
# 11  within_pitch_angle_lo    Tracker          506827        34.844
# 12  within_pitch_angle_hi    Tracker          448358        30.825
# 13      within_lhr_max_hi    Tracker          448284        30.819
# 14         within_ext_win   Momentum          425710        29.268
# 15         within_sig_win   Momentum          320841        22.058
#
#     Relative [%]                                      Description
# 0        100.000                             No selection applied
# 1         99.982                Tracks intersect tracker entrance
# 2         98.254                              Electron track fits
# 3         99.992  Downstream tracks (p_z > 0 at tracker entrance)
# 4         99.724                        One reco electron / event
# 5        100.000          Track parents are electrons (truth PID)
# 6         87.968                          Track fit quality > 0.2
# 7         71.913     t0 at tracker entrance (640 < t_0 < 1650 ns)
# 8         97.675                          >20 active tracker hits
# 9         58.354        Track fit t0 uncertainty (t0err < 0.9 ns)
# 10        98.674      Distance of closest approach (d_0 < 100 mm)
# 11        99.979            Extrapolated pitch angle (pz/pt > 0.5
# 12        88.464            Extrapolated pitch angle (pz/pt > 1.0
# 13        99.983       Loop helix maximum radius (R_max < 680 mm)
# 14        94.964            Extended window (100 < p < 110 MeV/c)
# 15        75.366          Signal window (103.6 < p < 104.9 MeV/c)

# %% [markdown]
# ### Efficiency & rates

# %%
display(results["analysis"].round(3))
# Out:
# 0                                 Type CE-like (wide) CE-like (ext)  \
# 0                                    k         448284        425710
# 1                                    N        4000000       4000000
# 2                              Eff [%]        11.2071      10.64275
# 3                       Eff Err$-$ [%]      -0.015763     -0.015409
# 4                       Eff Err$+$ [%]       0.015782      0.015429
# 5          Rate 1B [$\text{day}^{-1}$]       448284.0      425710.0
# 6   Rate 1B Err$-$ [$\text{day}^{-1}$]    -665.832908   -648.851954
# 7   Rate 1B Err$+$ [$\text{day}^{-1}$]     666.826281    649.845347
# 8          Rate 2B [$\text{day}^{-1}$]       448284.0      425710.0
# 9   Rate 2B Err$-$ [$\text{day}^{-1}$]    -665.832908   -648.851954
# 10  Rate 2B Err$+$ [$\text{day}^{-1}$]     666.826281    649.845347
#
# 0  CE-like (sig) No veto (wide) No veto (ext) No veto (sig)
# 0         320841              0             0             0
# 1        4000000         448284        425710        320841
# 2       8.021025          100.0         100.0         100.0
# 3       -0.01357      -0.000223     -0.000235     -0.000312
# 4       0.013591            0.0           0.0           0.0
# 5       320841.0            0.0           0.0           0.0
# 6    -563.292463            0.0           0.0           0.0
# 7     564.285972       1.139434      1.139434      1.139434
# 8       320841.0            0.0           0.0           0.0
# 9    -563.292463            0.0           0.0           0.0
# 10    564.285972       1.139434      1.139434      1.139434

# %% [markdown]
# ### Histograms

# %%
# Setup draw for this cutset
on_spill = "offspill" not in ana_label
draw = Draw(cutset_name=ana_label.split('_')[0], on_spill=on_spill)
# Define image directory
img_dir = f"../../../output/images/{ana_label}"
os.makedirs(img_dir, exist_ok=True)
# Out:
# [Plot] ⭐️ Initialised

# %%
draw.plot_mom_windows(results["hists"], out_path=f"{img_dir}/h1o_1x3_mom_windows.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020b_signal_onspill-LH_au/h1o_1x3_mom_windows.png

# %%
draw.plot_summary(results["hists"], out_path=f"{img_dir}/h1o_3x3_summary.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020b_signal_onspill-LH_au/h1o_3x3_summary.png

# %%
draw.plot_crv_z(results["hists"], out_path=f"{img_dir}/h1o_crv_z.png")
# Out:
# [Plot] ✅ 	Wrote ../../../output/images/SU2020b_signal_onspill-LH_au/h1o_crv_z.png

# %% [markdown]
# ### Background event info

# %%
print(results["event_info"])
# Out:
# None

# %%
if results["events"] is not None:
    from pyutils.pyprint import Print
    printer = Print()
    printer.print_n_events(results["events"], n_events = len(results["events"]))
