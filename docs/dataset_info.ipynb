# %% [markdown]
# ## Dataset information
#
# The total livetime and number of generated events per dataset definition, as used in the analysis.
#
# Livetimes are rounded to within 10,000 seconds, which is to the order of one day.

# %%
import pandas as pd
dataset_info = pd.read_csv("dataset_info.csv")
dataset_info_filtered = dataset_info.drop(4) # "MDC2020an" dataset
dataset_info_filtered = dataset_info_filtered.drop(["parent", "livetime_per_file_s", "estimated_total_livetime_days", "delta"], axis=1)
display(dataset_info_filtered)
# Out:
#                                              defname  n_files  \
# 0  nts.mu2e.CosmicCRYSignalAllOffSpillTriggered-L...      817
# 1  nts.mu2e.CosmicCRYSignalAllOnSpillTriggered.MD...      822
# 2  nts.mu2e.CosmicCRYSignalAllOnSpillTriggered.MD...      821
# 3  nts.mu2e.CosmicCRYSignalAllOnSpillTriggered.MD...      821
# 5  nts.mu2e.CeEndpointOnSpillTriggered.MDC2020au_...     1000
# 6  nts.mu2e.CeEndpointOnSpillTriggered.MDC2020aw_...     1000
# 7  nts.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_...     1000
#
#    estimated_total_livetime_s  actual_total_livetime_s  rounded_livetime_s  \
# 0                  10636849.8               10628800.0          10630000.0
# 1                  10701946.8               10693912.0          10690000.0
# 2                  10688927.4               10680900.0          10680000.0
# 3                  10688927.4               10680900.0          10680000.0
# 5                         NaN                      NaN                 NaN
# ...
